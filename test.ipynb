# %%
import os
import json
from openai import OpenAI
from dotenv import load_dotenv
import pymongo

# %%
myclient = pymongo.MongoClient(os.environ.get("MONGODB_URI_CH"))
mydb = myclient["DBExam"]
conversationCollection = mydb["Conversations"]
messagesCollection = mydb["Messages"]
userCollection = mydb["Users"]


print("--------")
print(conversationCollection)
print(messagesCollection)
print(userCollection)
print("--------")

initial_message = {
    "role": "system",
    "content": "M's testy time"
}
new_conversation = {
    "user_id": 12345,
    "messages": [initial_message]
}
print("1")
conversationCollection.insert_one(new_conversation)
print("2")
user_conversations = [new_conversation]
# Out:
# --------
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'DBExam'), 'Conversations')
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'DBExam'), 'Messages')
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'DBExam'), 'Users')
# --------
# 1
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[10], line 23
#      18 new_conversation = {
#      19     "user_id": 12345,
#      20     "messages": [initial_message]
#      21 }
#      22 print("1")
# ---> 23 conversationCollection.insert_one(new_conversation)
#      24 print("2")
#      25 user_conversations = [new_conversation]
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\collection.py:658, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     654     document["_id"] = ObjectId()  # type: ignore[index]
#     656 write_concern = self._write_concern_for(session)
#     657 return InsertOneResult(
# --> 658     self._insert_one(
#     659         document,
#     660         ordered=True,
#     661         write_concern=write_concern,
#     662         op_id=None,
#     663         bypass_doc_val=bypass_document_validation,
#     664         session=session,
#     665         comment=comment,
#     666     ),
#     667     write_concern.acknowledged,
#     668 )
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\collection.py:598, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     586     result = conn.command(
#     587         self.__database.name,
#     588         command,
#    (...)
#     593         retryable_write=retryable_write,
#     594     )
#     596     _check_write_command_response(result)
# --> 598 self.__database.client._retryable_write(
#     599     acknowledged, _insert_command, session, operation=_Op.INSERT
#     600 )
#     602 if not isinstance(doc, RawBSONDocument):
#     603     return doc.get("_id")
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:1569, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1555 """Execute an operation with consecutive retries if possible
#    1556
#    1557 Returns func()'s return value on success. On error retries the same
#    (...)
#    1566 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1567 """
#    1568 with self._tmp_session(session) as s:
# -> 1569     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:1455, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1450 # Ensure that the options supports retry_writes and there is a valid session not in
#    1451 # transaction, otherwise, we will not support retry behavior for this txn.
#    1452 retryable = bool(
#    1453     retryable and self.options.retry_writes and session and not session.in_transaction
#    1454 )
# -> 1455 return self._retry_internal(
#    1456     func=func,
#    1457     session=session,
#    1458     bulk=bulk,
#    1459     operation=operation,
#    1460     retryable=retryable,
#    1461     operation_id=operation_id,
#    1462 )
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:1501, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1464 @_csot.apply
#    1465 def _retry_internal(
#    1466     self,
#    (...)
#    1475     operation_id: Optional[int] = None,
#    1476 ) -> T:
#    1477     """Internal retryable helper for all client transactions.
#    1478
#    1479     :param func: Callback function we want to retry
#    (...)
#    1488     :return: Output of the calling func()
#    1489     """
#    1490     return _ClientConnectionRetryable(
#    1491         mongo_client=self,
#    1492         func=func,
#    1493         bulk=bulk,
#    1494         operation=operation,
#    1495         is_read=is_read,
#    1496         session=session,
#    1497         read_pref=read_pref,
#    1498         address=address,
#    1499         retryable=retryable,
#    1500         operation_id=operation_id,
# -> 1501     ).run()
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:2347, in _ClientConnectionRetryable.run(self)
#    2345 self._check_last_error(check_csot=True)
#    2346 try:
# -> 2347     return self._read() if self._is_read else self._write()
#    2348 except ServerSelectionTimeoutError:
#    2349     # The application may think the write was never attempted
#    2350     # if we raise ServerSelectionTimeoutError on the retry
#    2351     # attempt. Raise the original exception instead.
#    2352     self._check_last_error()
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:2450, in _ClientConnectionRetryable._write(self)
#    2448 max_wire_version = 0
#    2449 is_mongos = False
# -> 2450 self._server = self._get_server()
#    2451 with self._client._checkout(self._server, self._session) as conn:
#    2452     max_wire_version = conn.max_wire_version
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:2433, in _ClientConnectionRetryable._get_server(self)
#    2428 def _get_server(self) -> Server:
#    2429     """Retrieves a server object based on provided object context
#    2430
#    2431     :return: Abstraction to connect to server
#    2432     """
# -> 2433     return self._client._select_server(
#    2434         self._server_selector,
#    2435         self._session,
#    2436         self._operation,
#    2437         address=self._address,
#    2438         deprioritized_servers=self._deprioritized_servers,
#    2439         operation_id=self._operation_id,
#    2440     )
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:1316, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1314             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1315     else:
# -> 1316         server = topology.select_server(
#    1317             server_selector,
#    1318             operation,
#    1319             deprioritized_servers=deprioritized_servers,
#    1320             operation_id=operation_id,
#    1321         )
#    1322     return server
#    1323 except PyMongoError as exc:
#    1324     # Server selection errors in a transaction are transient.
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\topology.py:369, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     359 def select_server(
#     360     self,
#     361     selector: Callable[[Selection], Selection],
#    (...)
#     366     operation_id: Optional[int] = None,
#     367 ) -> Server:
#     368     """Like select_servers, but choose a random server if several match."""
# --> 369     server = self._select_server(
#     370         selector,
#     371         operation,
#     372         server_selection_timeout,
#     373         address,
#     374         deprioritized_servers,
#     375         operation_id=operation_id,
#     376     )
#     377     if _csot.get_timeout():
#     378         _csot.set_rtt(server.description.min_round_trip_time)
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\topology.py:347, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     338 def _select_server(
#     339     self,
#     340     selector: Callable[[Selection], Selection],
#    (...)
#     345     operation_id: Optional[int] = None,
#     346 ) -> Server:
# --> 347     servers = self.select_servers(
#     348         selector, operation, server_selection_timeout, address, operation_id
#     349     )
#     350     servers = _filter_servers(servers, deprioritized_servers)
#     351     if len(servers) == 1:
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\topology.py:254, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     251     server_timeout = server_selection_timeout
#     253 with self._lock:
# --> 254     server_descriptions = self._select_servers_loop(
#     255         selector, server_timeout, operation, operation_id, address
#     256     )
#     258     return [
#     259         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     260     ]
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\topology.py:304, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     293     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     294         _debug_log(
#     295             _SERVER_SELECTION_LOGGER,
#     296             message=_ServerSelectionStatusMessage.FAILED,
#    (...)
#     302             failure=self._error_message(selector),
#     303         )
# --> 304     raise ServerSelectionTimeoutError(
#     305         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     306     )
#     308 if not logged_waiting:
#     309     _info_log(
#     310         _SERVER_SELECTION_LOGGER,
#     311         message=_ServerSelectionStatusMessage.WAITING,
#    (...)
#     317         remainingTimeMS=int(end_time - time.monotonic()),
#     318     )
#
# ServerSelectionTimeoutError: localhost:27017: [WinError 10061] Der kunne ikke oprettes forbindelse, fordi destinationscomputeren aktivt nægtede det (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 66599f54d4e4c0855f469787, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [WinError 10061] Der kunne ikke oprettes forbindelse, fordi destinationscomputeren aktivt nægtede det (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
uri = "mongodb+srv://Username1:testcode123@cluster0.cflnrpd.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# if not user_conversations:
initial_message = {
    "role": "system",
    "content": "You are a helpful chatbot that answers the users questions. You will be given source material and chat history and you are to only answer the last user question given, grounded in the documents you are given. If the answer is not in the documents do not answer"
}
new_conversation = {
    "user_id": 2222222222,
    "messages": [initial_message]
}
print("1")
conversationCollection.insert_one(new_conversation)
print("2")
# Out:
# 1
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[8], line 11
#       6 new_conversation = {
#       7     "user_id": 2222222222,
#       8     "messages": [initial_message]
#       9 }
#      10 print("1")
# ---> 11 conversationCollection.insert_one(new_conversation)
#      12 print("2")
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\collection.py:658, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     654     document["_id"] = ObjectId()  # type: ignore[index]
#     656 write_concern = self._write_concern_for(session)
#     657 return InsertOneResult(
# --> 658     self._insert_one(
#     659         document,
#     660         ordered=True,
#     661         write_concern=write_concern,
#     662         op_id=None,
#     663         bypass_doc_val=bypass_document_validation,
#     664         session=session,
#     665         comment=comment,
#     666     ),
#     667     write_concern.acknowledged,
#     668 )
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\collection.py:598, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     586     result = conn.command(
#     587         self.__database.name,
#     588         command,
#    (...)
#     593         retryable_write=retryable_write,
#     594     )
#     596     _check_write_command_response(result)
# --> 598 self.__database.client._retryable_write(
#     599     acknowledged, _insert_command, session, operation=_Op.INSERT
#     600 )
#     602 if not isinstance(doc, RawBSONDocument):
#     603     return doc.get("_id")
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:1569, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1555 """Execute an operation with consecutive retries if possible
#    1556
#    1557 Returns func()'s return value on success. On error retries the same
#    (...)
#    1566 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1567 """
#    1568 with self._tmp_session(session) as s:
# -> 1569     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:1455, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1450 # Ensure that the options supports retry_writes and there is a valid session not in
#    1451 # transaction, otherwise, we will not support retry behavior for this txn.
#    1452 retryable = bool(
#    1453     retryable and self.options.retry_writes and session and not session.in_transaction
#    1454 )
# -> 1455 return self._retry_internal(
#    1456     func=func,
#    1457     session=session,
#    1458     bulk=bulk,
#    1459     operation=operation,
#    1460     retryable=retryable,
#    1461     operation_id=operation_id,
#    1462 )
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:1501, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1464 @_csot.apply
#    1465 def _retry_internal(
#    1466     self,
#    (...)
#    1475     operation_id: Optional[int] = None,
#    1476 ) -> T:
#    1477     """Internal retryable helper for all client transactions.
#    1478
#    1479     :param func: Callback function we want to retry
#    (...)
#    1488     :return: Output of the calling func()
#    1489     """
#    1490     return _ClientConnectionRetryable(
#    1491         mongo_client=self,
#    1492         func=func,
#    1493         bulk=bulk,
#    1494         operation=operation,
#    1495         is_read=is_read,
#    1496         session=session,
#    1497         read_pref=read_pref,
#    1498         address=address,
#    1499         retryable=retryable,
#    1500         operation_id=operation_id,
# -> 1501     ).run()
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:2347, in _ClientConnectionRetryable.run(self)
#    2345 self._check_last_error(check_csot=True)
#    2346 try:
# -> 2347     return self._read() if self._is_read else self._write()
#    2348 except ServerSelectionTimeoutError:
#    2349     # The application may think the write was never attempted
#    2350     # if we raise ServerSelectionTimeoutError on the retry
#    2351     # attempt. Raise the original exception instead.
#    2352     self._check_last_error()
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:2450, in _ClientConnectionRetryable._write(self)
#    2448 max_wire_version = 0
#    2449 is_mongos = False
# -> 2450 self._server = self._get_server()
#    2451 with self._client._checkout(self._server, self._session) as conn:
#    2452     max_wire_version = conn.max_wire_version
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:2433, in _ClientConnectionRetryable._get_server(self)
#    2428 def _get_server(self) -> Server:
#    2429     """Retrieves a server object based on provided object context
#    2430
#    2431     :return: Abstraction to connect to server
#    2432     """
# -> 2433     return self._client._select_server(
#    2434         self._server_selector,
#    2435         self._session,
#    2436         self._operation,
#    2437         address=self._address,
#    2438         deprioritized_servers=self._deprioritized_servers,
#    2439         operation_id=self._operation_id,
#    2440     )
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\mongo_client.py:1316, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1314             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1315     else:
# -> 1316         server = topology.select_server(
#    1317             server_selector,
#    1318             operation,
#    1319             deprioritized_servers=deprioritized_servers,
#    1320             operation_id=operation_id,
#    1321         )
#    1322     return server
#    1323 except PyMongoError as exc:
#    1324     # Server selection errors in a transaction are transient.
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\topology.py:369, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     359 def select_server(
#     360     self,
#     361     selector: Callable[[Selection], Selection],
#    (...)
#     366     operation_id: Optional[int] = None,
#     367 ) -> Server:
#     368     """Like select_servers, but choose a random server if several match."""
# --> 369     server = self._select_server(
#     370         selector,
#     371         operation,
#     372         server_selection_timeout,
#     373         address,
#     374         deprioritized_servers,
#     375         operation_id=operation_id,
#     376     )
#     377     if _csot.get_timeout():
#     378         _csot.set_rtt(server.description.min_round_trip_time)
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\topology.py:347, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     338 def _select_server(
#     339     self,
#     340     selector: Callable[[Selection], Selection],
#    (...)
#     345     operation_id: Optional[int] = None,
#     346 ) -> Server:
# --> 347     servers = self.select_servers(
#     348         selector, operation, server_selection_timeout, address, operation_id
#     349     )
#     350     servers = _filter_servers(servers, deprioritized_servers)
#     351     if len(servers) == 1:
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\topology.py:254, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     251     server_timeout = server_selection_timeout
#     253 with self._lock:
# --> 254     server_descriptions = self._select_servers_loop(
#     255         selector, server_timeout, operation, operation_id, address
#     256     )
#     258     return [
#     259         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     260     ]
#
# File c:\Users\Bruger\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymongo\topology.py:304, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     293     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     294         _debug_log(
#     295             _SERVER_SELECTION_LOGGER,
#     296             message=_ServerSelectionStatusMessage.FAILED,
#    (...)
#     302             failure=self._error_message(selector),
#     303         )
# --> 304     raise ServerSelectionTimeoutError(
#     305         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     306     )
#     308 if not logged_waiting:
#     309     _info_log(
#     310         _SERVER_SELECTION_LOGGER,
#     311         message=_ServerSelectionStatusMessage.WAITING,
#    (...)
#     317         remainingTimeMS=int(end_time - time.monotonic()),
#     318     )
#
# ServerSelectionTimeoutError: localhost:27017: [WinError 10061] Der kunne ikke oprettes forbindelse, fordi destinationscomputeren aktivt nægtede det (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 66599a38d4e4c0855f469784, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [WinError 10061] Der kunne ikke oprettes forbindelse, fordi destinationscomputeren aktivt nægtede det (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
