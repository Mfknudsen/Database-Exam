# %%
import xml.etree.ElementTree as ET
import mysql.connector
import logging
import os
from dotenv import load_dotenv
load_dotenv("../config.env",verbose=True)
# Out:
# True

# %%
def connect_to_db():
    return mysql.connector.connect(
        host="localhost",
        user=os.environ["sql_user"],
        password=os.environ["sql_password"],
        database="mydb"
    )

ns = {'ns': 'http://www.battlescribe.net/schema/catalogueSchema'}

def insert_faction(root, cursor):
    _name = root.get('name')
    _description = root.get('description')
    if _description is None:
        _description = ""
    _id = root.get('id')

    sql = "INSERT INTO Faction (name, description, id) VALUES (%s, %s,%s)"
    try:
        cursor.execute(sql, (_name, _description, _id))
    except Exception as e:
        logging.error("Error at %s", "insert_faction", exc_info=e)
        print(e)

    return _id

def insert_unit2(cursor, root, faction_id):
    sharedSelectionEntries = root.find('ns:sharedSelectionEntries', ns)

    if(sharedSelectionEntries == None):
        return

    for selectionEntry in sharedSelectionEntries:
        if "[Legends]" not in selectionEntry.get("name"):
            if selectionEntry.get("type") == "model" or selectionEntry.get("type") == "unit":

                _name = selectionEntry.get("name")
                _description = selectionEntry.get("description")
                if _description == None:
                    _description = ""
                _id = selectionEntry.get("id")

                sql = "INSERT INTO Unit (name, description, id, faction_id) VALUES (%s, %s,%s,%s)"
                try:
                    print("inserting unit", _name, _description, _id, faction_id)
                    cursor.execute(sql, (_name, _description, _id, faction_id))
                    parse_selectionEntry(cursor, selectionEntry, _id)
                    insert_keywords(cursor, selectionEntry, _id)
                    insert_costs(cursor, selectionEntry, _id)
                except Exception as e:
                    logging.error("Error at %s", "insert_unit", exc_info=e)
                    print(e)

def insert_keywords(cursor, selectionEntry, unit_id):
    keywords = selectionEntry.findall(".//ns:categoryLink", ns)
    for keyword in keywords:
        _name = keyword.get("name")
        _id = keyword.get("targetId")
        sql = "INSERT IGNORE INTO ModelKeyWord (text, id) VALUES (%s, %s)"
        sql_map = "INSERT IGNORE INTO unit_has_ModelKeyword (Unit_id, ModelKeyword_id) VALUES (%s, %s)"
        try:
            cursor.execute(sql, (_name, _id))
            cursor.execute(sql_map, (unit_id, _id))
        except Exception as e:
            logging.error("Error at %s", "insert_keywords", exc_info=e)
            print(e)

def parse_selectionEntry(cursor, selectionEntry, unit_id):
    profiles = selectionEntry.findall(".//ns:profile", ns)
    weapons = []
    for profile in profiles:
        if profile.get("typeName") == "Unit" or profile.get("typeName") == "Model":
            insert_model(cursor, profile, unit_id)
        if profile.get("typeName") == "Abilities":
            insert_abilities(cursor, profile, unit_id)
        if profile.get("typeName") == "Ranged Weapons" or profile.get("typeName") == "Melee Weapons":
            weapons.append(profile)

    for profile in weapons:
        insert_weapons(cursor, profile, unit_id)

def insert_weapons(cursor, profile, unit_id):
    _name = profile.get("name")
    _id = profile.get("id")
    c = profile.find(".//ns:characteristics", ns)

    _range = None
    _strength = None
    _ap = None
    _damage = None
    _attack = None
    _hit = None

    keywords = None

    for characteristic in c:
        if characteristic.get("name") == "Range":
            _range = characteristic.text
        if characteristic.get("name") == "S":
            _strength = characteristic.text
        if characteristic.get("name") == "AP":
            _ap = characteristic.text
        if characteristic.get("name") == "D":
            _damage = characteristic.text
        if characteristic.get("name") == "A":
            _attack = characteristic.text
        if characteristic.get("name") == "WS":
            _hit = characteristic.text
        if characteristic.get("name") == "BS":
            _hit = characteristic.text
        if characteristic.get("name") == "Keywords":
           keywords = characteristic

    sql = "INSERT INTO weapon (name, weapon_range, hit_skill, strength, armor_piercing, damage, id, attack, unit_id) VALUES (%s, %s,%s,%s,%s,%s,%s,%s,%s)"

    try:
        print("inserting weapon", _name, _hit, _strength, _ap, _damage, _id, _attack, unit_id)
        cursor.execute(sql, (_name, _range, _hit, _strength, _ap, _damage, _id, _attack, unit_id))
    except Exception as e:
        logging.error("Error at %s", "insert_weapons", exc_info=e)
        print("error!!!!")
        print(e)

    if(keywords != None):
        insert_weapon_keywords(cursor, keywords, _id)

def insert_weapon_keywords(cursor, characteristic, weapon_id):
    _keywords = characteristic.text
    # Check if the weapon has keywords
    if _keywords is None:
        return

    if len(_keywords) < 3:
        return
    keywords = characteristic.text.split(", ")

    for keyword in keywords:
        if keyword.replace("/n", "").replace(" ", "") == "":
            continue

        sql = "select * from weaponkeyword where name = %s"
        cursor.execute(sql, (keyword,))
        result = cursor.fetchone()
        if result is None or len(result) == 0:
            sql = "INSERT INTO weaponkeyword (name) VALUES (%s)"
            print("inserting keyword", keyword)
            cursor.execute(sql, (keyword,))
            cursor.execute("SELECT id FROM weaponkeyword WHERE name = %s", (keyword,))
            result = cursor.fetchone()

        sql = "INSERT INTO WeaponHasKeyword (Weapon_id, WeaponKeyword_id) VALUES (%s, %s)"
        print("inserting keyword relationship", weapon_id, result[0])
        cursor.execute(sql, (weapon_id, result[0]))

def insert_abilities(cursor, profile, unit_id):
    _name = profile.get("name")
    _id = profile.get("id")
    _description = profile.findall(".//ns:characteristic", ns)[0].text

    if(_description is None):
        _description = ""

    sql = "INSERT INTO modelability (name, description, id) VALUES (%s, %s,%s)"
    sql_map = "INSERT INTO unit_has_modelability (unit_id, ModelAbility_id) VALUES (%s, %s)"
    try:
        cursor.execute(sql, (_name, _description, _id))
        cursor.execute(sql_map, (unit_id, _id))
    except Exception as e:
        logging.error("Error at %s", "insert_abilities", exc_info=e)
        print(e)

def insert_model(cursor, model, unit_id):
    _name = model.get("name")
    _id = model.get("id")

    move = None
    leadership = None
    save = None
    toughness = None
    wounds = None
    oc = None
    keywords = None
    for characteristics in model.findall(".//ns:characteristic", ns):

        if characteristics.get("name") == "M":
            move = characteristics.text
        elif characteristics.get("name") == "LD":
            leadership = characteristics.text
        elif characteristics.get("name") == "SV":
            save = characteristics.text
        elif characteristics.get("name") == "T":
            toughness = characteristics.text
        elif characteristics.get("name") == "W":
            wounds = characteristics.text
        elif characteristics.get("name") == "OC":
            oc = characteristics.text
        elif characteristics.get("name") == "Keywords":
            keywords = characteristics

        sql_models = "INSERT INTO Model (id, name, move, toughness,wounds, leadership, save, unit_id, oc) VALUES (%s, %s,%s,%s, %s, %s,%s,%s,%s)"

    try:
        print("inserting model", _id, _name, move, toughness, wounds, leadership, save, unit_id, oc)
        cursor.execute(sql_models, (_id, _name, move, toughness, wounds, leadership, save, unit_id, oc))

    except Exception as e:
        logging.error("Error at %s", "insert_model", exc_info=e)
        print(e)

    if(keywords != None):
        insert_keywords(cursor, keywords, unit_id)

def insert_ally(cursor, root):
    r = root.find(".//ns:catalogueLinks", ns)
    if(r is None):
        return
    _id = root.get("id")
    for re in r:
        sql = "select * from faction where name = %s"
        cursor.execute(sql, (re.get("name"),))
        result = cursor.fetchone()
        if(result is not None):
            sql = "insert into CanTakeAsAllied (faction_id, allied_id) values (%s, %s)"
            print("inserting ally relationship", _id, result[0])
            cursor.execute(sql, (_id, result[0]))

def insert_costs(cursor, selectionEntry, unit_id):
    costs = selectionEntry.find(".//ns:costs", ns)
    sql = "insert into UnitCost (unit_id, cost, model_count) values (%s, %s, %s)"
  
    if(costs is not None):
        for c in costs:
            try:
                print("inserting unit cost", unit_id, c.get("value"), "default")
                cursor.execute(sql, (unit_id, c.get("value"), "default"))
            except Exception as e:
                logging.error("Error at %s", "insert_cost_default", exc_info=e)
                print(e)

    modifiers = selectionEntry.find(".//ns:modifiers", ns)

    if modifiers is None:
        return

    for m in modifiers:
        #Modifiers about cost have this id
        if m.get("field") != "51b2-306e-1021-d207":
            continue
        
        values = m.findall(".//ns:condition", ns)    

        for v in values:
            try:
                print("inserting unit cost", unit_id,m.get("value"), v.get("type")+ " " +v.get("value"))
                cursor.execute(sql, (unit_id, m.get("value"),  v.get("type")+ " " +v.get("value")))
            except Exception as e:
                logging.error("Error at %s", "insert_cost_modifier", exc_info=e)
                print(e)



def parse_cat_file(filename):
    tree = ET.parse(filename)
    root = tree.getroot()
    return root

def ingest_data(root, cursor):
    faction_id = insert_faction(root, cursor)
    insert_unit2(cursor, root, faction_id)
    insert_ally(cursor, root)
    db_connection.commit()

def clear_all_tables(cursor):
    # Get all table names

    # Iterate over all tables and delete all records
    try:
        cursor.execute(f"DELETE FROM `CanTakeAsAllied`")
        cursor.execute(f"DELETE FROM `WeaponHasKeyword`")
        cursor.execute(f"DELETE FROM `WeaponKeyword`")
        cursor.execute(f"DELETE FROM `Unit_has_ModelKeyword`")
        cursor.execute(f"DELETE FROM `Weapon`")
        cursor.execute(f"DELETE FROM `Model`")
        cursor.execute(f"DELETE FROM `ModelKeyword`")
        cursor.execute(f"DELETE FROM `Unit_has_ModelAbility`")
        cursor.execute(f"DELETE FROM `ModelAbility`")
        cursor.execute(f"DELETE FROM `UnitCost`")
        cursor.execute(f"DELETE FROM `Unit`")
        cursor.execute(f"DELETE FROM `Faction`")

        db_connection.commit()

    except mysql.connector.Error as err:
        print(f"Something went wrong: {err}")

# %%
db_connection = connect_to_db()
cursor = db_connection.cursor(buffered=True)

# %%
names = os.listdir("./wh40k-10e")
clear_all_tables(cursor)

for n in names:
    if(".cat" not in n):
        continue

    print("ingesting for file: " + n)

    root = parse_cat_file("./wh40k-10e/" + n)
    ingest_data(root, cursor)

for n in names:
    if(".cat" not in n):
        continue
    root = parse_cat_file("./wh40k-10e/" + n)
    insert_ally(cursor, root)
    
db_connection.close()
# Out:
# ingesting for file: Aeldari - Aeldari Library.cat
# inserting unit Asurmen  828d-840a-9a67-9074 dfcf-1214-b57-2205
# inserting model dd63-cf49-2bda-19d2 Asurmen 7" 3 5 6+ 2+ 828d-840a-9a67-9074 1
# inserting weapon The Bloody Twins 2+ 4 -1 2 5ed6-602b-128c-54c5 6 828d-840a-9a67-9074
# inserting keyword Assault
# inserting keyword relationship 5ed6-602b-128c-54c5 70
# inserting keyword Lethal Hits
# inserting keyword relationship 5ed6-602b-128c-54c5 71
# inserting keyword Pistol
# inserting keyword relationship 5ed6-602b-128c-54c5 72
# inserting weapon The Sword of Asur 2+ 6 -3 3 25e2-1809-549b-55e 6 828d-840a-9a67-9074
# inserting keyword Devastating Wounds
# inserting keyword relationship 25e2-1809-549b-55e 73
# inserting unit cost 828d-840a-9a67-9074 0 default
# inserting unit Autarch Skyrunner  69f4-c990-93b4-20fc dfcf-1214-b57-2205
# inserting model 1d04-ad57-ec7c-8c47 Autarch Skyrunner 14" 4 5 6+ 3+ 69f4-c990-93b4-20fc 2
# inserting weapon Twin Shuriken Catapult 2+ 4 -1 1 20e3-117a-27ce-4adb 2 69f4-c990-93b4-20fc
# inserting keyword relationship 20e3-117a-27ce-4adb 70
# inserting keyword Twin Linked
# inserting keyword relationship 20e3-117a-27ce-4adb 74
# inserting weapon Laser Lance 2+ 6 -3 2 1ced-28e0-8ca5-fa63 1 69f4-c990-93b4-20fc
# inserting keyword relationship 1ced-28e0-8ca5-fa63 70
# inserting weapon Laser Lance 2+ 4 -3 2 4059-c7fa-d548-76f7 4 69f4-c990-93b4-20fc
# inserting keyword Lance
# inserting keyword relationship 4059-c7fa-d548-76f7 75
# inserting weapon Dragon Fusion Gun 2+ 9 -4 D6 ec3e-60a-9e2-5be0 1 69f4-c990-93b4-20fc
# inserting keyword relationship ec3e-60a-9e2-5be0 70
# inserting keyword Melta 3
# inserting keyword relationship ec3e-60a-9e2-5be0 76
# inserting weapon Banshee Blade 2+ 4 -3 1 2950-e03f-500-dfad 5 69f4-c990-93b4-20fc
# inserting unit cost 69f4-c990-93b4-20fc 0 default
# inserting unit Autarch  df57-7a59-75eb-ce63 dfcf-1214-b57-2205
# inserting model f510-fc53-8732-1d5f Autarch 7" 3 4 6+ 3+ df57-7a59-75eb-ce63 1
# inserting weapon Shuriken Pistol 2+ 4 -1 1 b007-42cc-f95e-c70b 1 df57-7a59-75eb-ce63
# inserting keyword relationship b007-42cc-f95e-c70b 70
# inserting keyword relationship b007-42cc-f95e-c70b 72
# inserting weapon ➤ Reaper Launcher - Starshot 3+ 8 -2 2 6da7-5d68-1c4e-a283 1 df57-7a59-75eb-ce63
# inserting keyword Heavy
# inserting keyword relationship 6da7-5d68-1c4e-a283 77
# inserting weapon ➤ Reaper Launcher - Starswarm 3+ 5 -1 1 8ee3-da64-8ae5-8de2 2 df57-7a59-75eb-ce63
# inserting keyword relationship 8ee3-da64-8ae5-8de2 77
# inserting weapon Death Spinner N/A 4 0 1 17a5-68c4-26f-f9f8 D6 df57-7a59-75eb-ce63
# inserting keyword relationship 17a5-68c4-26f-f9f8 73
# inserting keyword Torrent
# inserting keyword relationship 17a5-68c4-26f-f9f8 78
# inserting weapon Dragon Fusion Gun 2+ 9 -4 D6 35a0-f0f1-196f-b935 1 df57-7a59-75eb-ce63
# inserting keyword relationship 35a0-f0f1-196f-b935 70
# inserting keyword relationship 35a0-f0f1-196f-b935 76
# inserting weapon Fusion Pistol 2+ 8 -4 D3 3768-58f6-230d-fca2 1 df57-7a59-75eb-ce63
# inserting keyword relationship 3768-58f6-230d-fca2 70
# inserting keyword Melta 2
# inserting keyword relationship 3768-58f6-230d-fca2 79
# inserting keyword relationship 3768-58f6-230d-fca2 72
# inserting weapon Scorpion Chainsword 2+ 5 0 1 59d8-e8ae-c450-d308 6 df57-7a59-75eb-ce63
# inserting keyword Sustained Hits 1
# inserting keyword relationship 59d8-e8ae-c450-d308 80
# inserting weapon Banshee Blade 2+ 4 -3 1 5f74-ecb8-eae6-18a0 5 df57-7a59-75eb-ce63
# inserting weapon Star Glaive 3+ 6 -2 2 4052-a32d-2b88-d077 5 df57-7a59-75eb-ce63
# inserting unit cost df57-7a59-75eb-ce63 0 default
# inserting unit Autarch Wayleaper  497a-263e-966a-5a15 dfcf-1214-b57-2205
# inserting model c43b-8035-15bf-639 Autarch Wayleaper 14" 3 4 6+ 3+ 497a-263e-966a-5a15 1
# inserting weapon Shuriken Pistol 2+ 4 -1 1 1b0-a7e2-7bdf-7d06 1 497a-263e-966a-5a15
# inserting keyword relationship 1b0-a7e2-7bdf-7d06 70
# inserting keyword relationship 1b0-a7e2-7bdf-7d06 72
# inserting weapon ➤ Reaper Launcher - Starshot 3+ 8 -2 2 c90e-f8f-476e-c691 1 497a-263e-966a-5a15
# inserting keyword relationship c90e-f8f-476e-c691 77
# inserting weapon ➤ Reaper Launcher - Starswarm 3+ 5 -1 1 b0b0-6a0-db7c-6c90 2 497a-263e-966a-5a15
# inserting keyword relationship b0b0-6a0-db7c-6c90 77
# inserting weapon Death Spinner N/A 4 0 1 5850-69f4-86d7-75d2 D6 497a-263e-966a-5a15
# inserting keyword relationship 5850-69f4-86d7-75d2 73
# inserting keyword relationship 5850-69f4-86d7-75d2 78
# inserting weapon Dragon Fusion Gun 2+ 9 -4 D6 ac7d-ee37-299b-3914 1 497a-263e-966a-5a15
# inserting keyword relationship ac7d-ee37-299b-3914 70
# inserting keyword relationship ac7d-ee37-299b-3914 76
# inserting weapon Fusion Pistol 2+ 8 -4 D3 9d51-64a7-3571-e9dd 1 497a-263e-966a-5a15
# inserting keyword relationship 9d51-64a7-3571-e9dd 70
# inserting keyword relationship 9d51-64a7-3571-e9dd 79
# inserting keyword relationship 9d51-64a7-3571-e9dd 72
# inserting weapon Scorpion Chainsword 2+ 5 0 1 4b59-bdf9-8382-fe50 6 497a-263e-966a-5a15
# inserting keyword relationship 4b59-bdf9-8382-fe50 80
# inserting weapon Banshee Blade 2+ 4 -3 1 b2-5218-23eb-1801 5 497a-263e-966a-5a15
# inserting weapon Star Glaive 3+ 6 -2 2 c48e-b61-26a5-6d84 5 497a-263e-966a-5a15
# inserting unit cost 497a-263e-966a-5a15 0 default
# inserting unit Avatar of Khaine  554c-8b4f-1059-28a7 dfcf-1214-b57-2205
# inserting model d900-d532-41a1-3908 Avatar of Khaine 10" 12 14 6+ 2+ 554c-8b4f-1059-28a7 5
# inserting weapon The Wailing Doom 2+ 16 -4 D6+2 c775-3c5d-2ff0-fa08 1 554c-8b4f-1059-28a7
# inserting keyword Sustained Hits D3
# inserting keyword relationship c775-3c5d-2ff0-fa08 81
# inserting weapon ➤ The Wailing Doom - Strike 2+ 14 -4 D6+2 3778-dd6-1620-100d 6 554c-8b4f-1059-28a7
# inserting weapon ➤ The Wailing Doom - Sweep 2+ 7 -2 2 c94a-186d-ecca-af83 12 554c-8b4f-1059-28a7
# inserting unit cost 554c-8b4f-1059-28a7 0 default
# inserting unit Baharroth  8732-df2f-a542-805f dfcf-1214-b57-2205
# inserting model f375-575e-d1f5-25f0 Baharroth 14" 3 5 6+ 2+ 8732-df2f-a542-805f 1
# inserting weapon Fury of the Tempest 2+ 6 -1 2 57f8-addc-b405-fb4e 4 8732-df2f-a542-805f
# inserting keyword relationship 57f8-addc-b405-fb4e 70
# inserting keyword relationship 57f8-addc-b405-fb4e 71
# inserting weapon The Shining Blade 2+ 5 -2 2 5de6-f60b-6be-5628 6 8732-df2f-a542-805f
# inserting keyword relationship 5de6-f60b-6be-5628 80
# inserting unit cost 8732-df2f-a542-805f 0 default
# inserting unit Corsair Voidreavers  cc68-ad19-7285-7a11 dfcf-1214-b57-2205
# inserting model 57e2-27b5-2c68-cb6e Corsair Voidreavers 7" 3 1 6+ 4+ cc68-ad19-7285-7a11 2
# inserting weapon Aeldari power sword 3+ 4 -2 1 718d-5071-8e11-3cb6 2 cc68-ad19-7285-7a11
# inserting weapon Close combat weapon 3+ 3 0 1 4e1-c37e-9f8d-c7e5 3 cc68-ad19-7285-7a11
# inserting weapon Neuro disruptor 3+ 4 0 1 1cf4-43f7-4ff2-b8a4 1 cc68-ad19-7285-7a11
# inserting keyword Anti-Infantry 2+
# inserting keyword relationship 1cf4-43f7-4ff2-b8a4 82
# inserting keyword relationship 1cf4-43f7-4ff2-b8a4 70
# inserting keyword relationship 1cf4-43f7-4ff2-b8a4 72
# inserting weapon Shuriken rifle 3+ 4 -1 1 2522-d81b-7b47-3b25 1 cc68-ad19-7285-7a11
# inserting keyword relationship 2522-d81b-7b47-3b25 70
# inserting keyword Rapid Fire 1
# inserting keyword relationship 2522-d81b-7b47-3b25 83
# inserting weapon Shuriken pistol 3+ 4 -1 1 4328-f12e-e23a-62d9 1 cc68-ad19-7285-7a11
# inserting keyword relationship 4328-f12e-e23a-62d9 70
# inserting keyword relationship 4328-f12e-e23a-62d9 72
# inserting weapon Shuriken cannon 3+ 6 -1 2 5e54-8910-ae1-1a8f 3 cc68-ad19-7285-7a11
# inserting keyword relationship 5e54-8910-ae1-1a8f 80
# inserting weapon Wraithcannon 3+ 14 -4 D6 9f0d-2a87-98eb-5cfb 1 cc68-ad19-7285-7a11
# inserting keyword relationship 9f0d-2a87-98eb-5cfb 73
# inserting weapon Close combat weapon 3+ 3 0 1 95cf-7230-938c-c6d 3 cc68-ad19-7285-7a11
# inserting weapon Shuriken pistol 3+ 4 -1 1 b4a4-e1e8-9cd7-14d3 1 cc68-ad19-7285-7a11
# inserting keyword relationship b4a4-e1e8-9cd7-14d3 70
# inserting keyword relationship b4a4-e1e8-9cd7-14d3 72
# inserting weapon Corsair blaster 3+ 8 -4 D6+1 147b-c104-ef93-7111 1 cc68-ad19-7285-7a11
# inserting keyword relationship 147b-c104-ef93-7111 70
# inserting weapon Close combat weapon 3+ 3 0 1 d4f6-ecc1-3709-4207 3 cc68-ad19-7285-7a11
# inserting weapon Shuriken pistol 3+ 4 -1 1 d1da-925a-898e-d699 1 cc68-ad19-7285-7a11
# inserting keyword relationship d1da-925a-898e-d699 70
# inserting keyword relationship d1da-925a-898e-d699 72
# inserting weapon Shuriken pistol 3+ 4 -1 1 6b7-807e-e8b4-69cc 1 cc68-ad19-7285-7a11
# inserting keyword relationship 6b7-807e-e8b4-69cc 70
# inserting keyword relationship 6b7-807e-e8b4-69cc 72
# inserting weapon Aeldari power sword 3+ 4 -2 1 29a6-f7d3-dddc-c8c3 2 cc68-ad19-7285-7a11
# inserting weapon Shuriken rifle 3+ 4 -1 1 efc9-b21c-3ce-515 1 cc68-ad19-7285-7a11
# inserting keyword relationship efc9-b21c-3ce-515 70
# inserting keyword relationship efc9-b21c-3ce-515 83
# inserting weapon Close combat weapon 3+ 3 0 1 840e-fede-3d49-ce7e 3 cc68-ad19-7285-7a11
# inserting weapon Corsair shredder N/A 6 0 1 d3c9-151e-99c0-8adc D6 cc68-ad19-7285-7a11
# inserting keyword relationship d3c9-151e-99c0-8adc 70
# inserting keyword relationship d3c9-151e-99c0-8adc 78
# inserting weapon Close combat weapon 3+ 3 0 1 76dd-2da0-cf09-e374 3 cc68-ad19-7285-7a11
# inserting weapon Shuriken pistol 3+ 4 -1 1 59b5-e45a-e376-8ccb 1 cc68-ad19-7285-7a11
# inserting keyword relationship 59b5-e45a-e376-8ccb 70
# inserting keyword relationship 59b5-e45a-e376-8ccb 72
# inserting unit cost cc68-ad19-7285-7a11 0 default
# inserting unit cost cc68-ad19-7285-7a11 140 greaterThan 5
# inserting unit Corsair Voidscarred  cbb7-6669-a014-36fe dfcf-1214-b57-2205
# inserting model 6716-f0ea-323f-388a Corsair Voidscarred 7" 3 1 6+ 4+ cbb7-6669-a014-36fe 1
# inserting weapon Aeldari power sword 3+ 4 -2 1 9c58-4545-89d0-5149 3 cbb7-6669-a014-36fe
# inserting weapon Close combat weapon 3+ 3 0 1 c31-7d39-be61-c880 3 cbb7-6669-a014-36fe
# inserting weapon Neuro disruptor 3+ 4 0 1 ec82-e35e-3aa7-a32f 1 cbb7-6669-a014-36fe
# inserting keyword relationship ec82-e35e-3aa7-a32f 82
# inserting keyword relationship ec82-e35e-3aa7-a32f 70
# inserting keyword relationship ec82-e35e-3aa7-a32f 72
# inserting weapon Shuriken pistol 3+ 4 -1 1 f7e0-7ba3-ad65-d110 1 cbb7-6669-a014-36fe
# inserting keyword relationship f7e0-7ba3-ad65-d110 70
# inserting keyword relationship f7e0-7ba3-ad65-d110 72
# inserting weapon Shuriken rifle 3+ 4 -1 1 a6a4-25c4-dffa-19fd 1 cbb7-6669-a014-36fe
# inserting keyword relationship a6a4-25c4-dffa-19fd 70
# inserting keyword relationship a6a4-25c4-dffa-19fd 83
# inserting weapon Shuriken cannon 3+ 6 -1 2 aafa-71a6-a0c6-634f 3 cbb7-6669-a014-36fe
# inserting keyword relationship aafa-71a6-a0c6-634f 80
# inserting weapon Wraithcannon 3+ 14 -4 D6 a7eb-b6c3-40a7-b690 1 cbb7-6669-a014-36fe
# inserting keyword relationship a7eb-b6c3-40a7-b690 73
# inserting weapon Close combat weapon 3+ 3 0 1 3215-801a-7bc2-196c 3 cbb7-6669-a014-36fe
# inserting weapon Shuriken pistol 3+ 4 -1 1 d466-24fa-3a90-7241 1 cbb7-6669-a014-36fe
# inserting keyword relationship d466-24fa-3a90-7241 70
# inserting keyword relationship d466-24fa-3a90-7241 72
# inserting weapon Corsair shredder N/A 6 0 1 3191-c0e0-5c1-be23 D6 cbb7-6669-a014-36fe
# inserting keyword relationship 3191-c0e0-5c1-be23 70
# inserting keyword relationship 3191-c0e0-5c1-be23 78
# inserting weapon Corsair blaster 3+ 8 -4 D6+1 b517-590c-1ca4-21b3 1 cbb7-6669-a014-36fe
# inserting keyword relationship b517-590c-1ca4-21b3 70
# inserting weapon Close combat weapon 3+ 3 0 1 8ffa-4f2e-16ce-68bd 3 cbb7-6669-a014-36fe
# inserting weapon Shuriken pistol 3+ 4 -1 1 b58f-23df-db9f-2446 1 cbb7-6669-a014-36fe
# inserting keyword relationship b58f-23df-db9f-2446 70
# inserting keyword relationship b58f-23df-db9f-2446 72
# inserting weapon Shuriken pistol 3+ 4 -1 1 7e70-e14b-caf1-d229 1 cbb7-6669-a014-36fe
# inserting keyword relationship 7e70-e14b-caf1-d229 70
# inserting keyword relationship 7e70-e14b-caf1-d229 72
# inserting weapon Aeldari power sword 3+ 4 -2 1 020d-c907-8c4f-136a 3 cbb7-6669-a014-36fe
# inserting weapon Close combat weapon 3+ 3 0 1 ca29-d35c-d80d-e0f0 3 cbb7-6669-a014-36fe
# inserting weapon Ranger long rifle 3+ 4 -1 2 24be-051b-3fa0-becb 1 cbb7-6669-a014-36fe
# inserting keyword relationship 24be-051b-3fa0-becb 77
# inserting keyword Precision
# inserting keyword relationship 24be-051b-3fa0-becb 84
# inserting weapon Close combat weapon 3+ 3 0 1 140b-6979-d054-f64d 3 cbb7-6669-a014-36fe
# inserting weapon Shuriken pistol 3+ 4 -1 1 c9d7-5156-da34-707d 1 cbb7-6669-a014-36fe
# inserting keyword relationship c9d7-5156-da34-707d 70
# inserting keyword relationship c9d7-5156-da34-707d 72
# inserting weapon Shuriken pistol 3+ 4 -1 1 1a4f-31a3-7ef8-ca7e 1 cbb7-6669-a014-36fe
# inserting keyword relationship 1a4f-31a3-7ef8-ca7e 70
# inserting keyword relationship 1a4f-31a3-7ef8-ca7e 72
# inserting weapon Paired Hekatarii blades 2+ 3 -2 1 5d30-bb47-4450-5ca7 4 cbb7-6669-a014-36fe
# inserting keyword Twin-Linked
# inserting keyword relationship 5d30-bb47-4450-5ca7 85
# inserting weapon Close combat weapon 3+ 3 0 1 5791-bd34-4550-c914 3 cbb7-6669-a014-36fe
# inserting weapon Aeldari power sword 3+ 4 -2 1 1a9e-8b6e-c61e-d52d 3 cbb7-6669-a014-36fe
# inserting weapon Shuriken pistol 3+ 4 -1 1 cf21-0a44-fc64-9370 1 cbb7-6669-a014-36fe
# inserting keyword relationship cf21-0a44-fc64-9370 70
# inserting keyword relationship cf21-0a44-fc64-9370 72
# inserting weapon Close combat weapon 3+ 3 0 1 28f8-87f0-d9c3-f2fe 3 cbb7-6669-a014-36fe
# inserting weapon Shuriken pistol 3+ 4 -1 1 15e7-18a1-427-8952 1 cbb7-6669-a014-36fe
# inserting keyword relationship 15e7-18a1-427-8952 70
# inserting keyword relationship 15e7-18a1-427-8952 72
# inserting weapon Executioner 3+ 6 -2 D3 b1a0-fa8a-d5d1-2d1d 3 cbb7-6669-a014-36fe
# inserting keyword relationship b1a0-fa8a-d5d1-2d1d 82
# inserting keyword Psychic
# inserting keyword relationship b1a0-fa8a-d5d1-2d1d 86
# inserting weapon Witch staff 2+ 3 0 D3 b6e5-ec08-69dc-228e 2 cbb7-6669-a014-36fe
# inserting keyword relationship b6e5-ec08-69dc-228e 82
# inserting keyword relationship b6e5-ec08-69dc-228e 86
# inserting weapon Close combat weapon 3+ 3 0 1 f0a6-b8c7-7fed-f409 3 cbb7-6669-a014-36fe
# inserting weapon Shuriken pistol 3+ 4 -1 1 e404-9e71-334b-88f1 1 cbb7-6669-a014-36fe
# inserting keyword relationship e404-9e71-334b-88f1 70
# inserting keyword relationship e404-9e71-334b-88f1 72
# inserting weapon Fusion pistol 3+ 8 -4 D3 666c-aaee-a589-defe 1 cbb7-6669-a014-36fe
# inserting keyword relationship 666c-aaee-a589-defe 70
# inserting keyword relationship 666c-aaee-a589-defe 79
# inserting keyword relationship 666c-aaee-a589-defe 72
# inserting weapon Close combat weapon 3+ 3 0 1 e8f0-b0a6-46ca-f186 3 cbb7-6669-a014-36fe
# inserting weapon Shuriken rifle 3+ 4 -1 1 067d-46f9-041b-1b29 1 cbb7-6669-a014-36fe
# inserting keyword relationship 067d-46f9-041b-1b29 70
# inserting keyword relationship 067d-46f9-041b-1b29 83
# inserting weapon Close combat weapon 3+ 3 0 1 d18-a9c1-74f3-2183 3 cbb7-6669-a014-36fe
# inserting weapon Shuriken pistol 3+ 4 -1 1 c837-6f07-ea8-8185 1 cbb7-6669-a014-36fe
# inserting keyword relationship c837-6f07-ea8-8185 70
# inserting keyword relationship c837-6f07-ea8-8185 72
# inserting weapon Aeldari power sword 3+ 4 -2 1 1b68-c922-541-5c36 3 cbb7-6669-a014-36fe
# inserting weapon Close combat weapon 3+ 3 0 1 c0c9-3c12-f1f0-f331 3 cbb7-6669-a014-36fe
# inserting unit cost cbb7-6669-a014-36fe 0 default
# inserting unit cost cbb7-6669-a014-36fe 180 greaterThan 5
# inserting unit Crimson Hunter  90c9-aaac-5ef8-f043 dfcf-1214-b57-2205
# inserting model 8fca-1832-3529-2c34 Crimson Hunter 20+" 8 12 6+ 3+ 90c9-aaac-5ef8-f043 0
# inserting weapon Wraithbone Hull 4+ 6 0 1 475f-be45-76c1-af1b 3 90c9-aaac-5ef8-f043
# inserting weapon Pulse Laser 3+ 9 -2 D6 18d5-2884-50c6-46f7 3 90c9-aaac-5ef8-f043
# inserting weapon Starcannon 3+ 8 -3 2 d917-b60b-fa1c-f0c7 2 90c9-aaac-5ef8-f043
# inserting weapon Bright Lance 3+ 12 -3 D6+2 872e-1cf8-23a8-f6d7 1 90c9-aaac-5ef8-f043
# inserting unit cost 90c9-aaac-5ef8-f043 0 default
# inserting unit Dark Reapers  6863-bf42-238a-fd0b dfcf-1214-b57-2205
# inserting model 7cf5-b6b9-1e9e-3d5a Dark Reaper Exarch 6" 3 2 6+ 3+ 6863-bf42-238a-fd0b 1
# inserting model 2d38-f63e-595c-e486 Dark Reaper 6" 3 1 6+ 3+ 6863-bf42-238a-fd0b 1
# inserting weapon Shuriken Cannon 3+ 6 -1 2 b92d-7384-5b19-7953 3 6863-bf42-238a-fd0b
# inserting keyword Ignores Cover
# inserting keyword relationship b92d-7384-5b19-7953 87
# inserting keyword relationship b92d-7384-5b19-7953 80
# inserting weapon Tempest Launcher 3+ 4 -1 1 7212-ed2c-3db-f27b 2D6 6863-bf42-238a-fd0b
# inserting keyword Blast
# inserting keyword relationship 7212-ed2c-3db-f27b 88
# inserting keyword Indirect Fire
# inserting keyword relationship 7212-ed2c-3db-f27b 89
# inserting weapon ➤ Aeldari Missile Launcher - Starshot 3+ 10 -2 D6 a368-5971-ff9f-886 1 6863-bf42-238a-fd0b
# inserting keyword relationship a368-5971-ff9f-886 87
# inserting weapon ➤ Aeldari Missile Launcher - Sunburst 3+ 4 -1 1 3790-7b32-4244-9a01 D6 6863-bf42-238a-fd0b
# inserting keyword relationship 3790-7b32-4244-9a01 88
# inserting keyword relationship 3790-7b32-4244-9a01 87
# inserting weapon ➤ Reaper Launcher - Starshot 3+ 8 -2 2 cd1f-a5a-cfc6-5d6e 1 6863-bf42-238a-fd0b
# inserting keyword relationship cd1f-a5a-cfc6-5d6e 87
# inserting weapon ➤ Reaper Launcher - Starswarm 3+ 5 -1 1 f45e-95ef-70ce-afdd 2 6863-bf42-238a-fd0b
# inserting keyword relationship f45e-95ef-70ce-afdd 87
# inserting weapon Close combat weapon 3+ 3 0 1 a1b5-a0a1-1473-3ab 2 6863-bf42-238a-fd0b
# inserting weapon ➤ Reaper Launcher - Starshot 3+ 8 -2 2 cd93-3e51-84a6-4250 1 6863-bf42-238a-fd0b
# inserting keyword relationship cd93-3e51-84a6-4250 87
# inserting weapon ➤ Reaper Launcher - Starswarm 3+ 5 -1 1 52f3-9255-65ed-5fdc 2 6863-bf42-238a-fd0b
# inserting keyword relationship 52f3-9255-65ed-5fdc 87
# inserting weapon Close combat weapon 3+ 3 0 1 ccf2-ece5-886f-b249 2 6863-bf42-238a-fd0b
# inserting unit cost 6863-bf42-238a-fd0b 0 default
# inserting unit cost 6863-bf42-238a-fd0b 160 greaterThan 5
# inserting unit Death Jester  5768-1f87-3a16-d901 dfcf-1214-b57-2205
# inserting model 2c8-51cd-9829-c3cd Death Jester 8" 3 4 6+ 6+ 5768-1f87-3a16-d901 1
# inserting weapon Shrieker Cannon 2+ 6 -1 2 6ca-5831-21c6-250 3 5768-1f87-3a16-d901
# inserting keyword relationship 6ca-5831-21c6-250 73
# inserting weapon Jester's Blade 2+ 4 0 1 1eff-7fab-182b-448a 4 5768-1f87-3a16-d901
# inserting unit cost 5768-1f87-3a16-d901 90 default
# inserting unit Dire Avengers  e6c2-f3b2-6d3e-c3d3 dfcf-1214-b57-2205
# inserting model 289d-76b1-de24-bb6e Dire Avenger 7" 3 1 6+ 4+ e6c2-f3b2-6d3e-c3d3 1
# inserting model 74b4-71be-6ae6-125d Dire Avenger Exarch 7" 3 2 6+ 4+ e6c2-f3b2-6d3e-c3d3 1
# inserting weapon Avenger Shuriken Catapult 3+ 4 -1 1 a37e-5c68-1dbb-9788 3 e6c2-f3b2-6d3e-c3d3
# inserting keyword relationship a37e-5c68-1dbb-9788 70
# inserting keyword relationship a37e-5c68-1dbb-9788 71
# inserting weapon Avenger Shuriken Catapult 3+ 4 -1 1 99c1-221c-c9ab-85ef 3 e6c2-f3b2-6d3e-c3d3
# inserting keyword relationship 99c1-221c-c9ab-85ef 70
# inserting keyword relationship 99c1-221c-c9ab-85ef 71
# inserting weapon Diresword 3+ 4 -2 1 c3fc-b165-ced3-8c6b 3 e6c2-f3b2-6d3e-c3d3
# inserting keyword relationship c3fc-b165-ced3-8c6b 73
# inserting weapon Shuriken Pistol 3+ 4 -1 1 16f6-7edd-9e-5863 1 e6c2-f3b2-6d3e-c3d3
# inserting keyword relationship 16f6-7edd-9e-5863 70
# inserting keyword relationship 16f6-7edd-9e-5863 72
# inserting weapon Shuriken Pistol 3+ 4 -1 1 8532-59f6-df1e-e9c6 1 e6c2-f3b2-6d3e-c3d3
# inserting keyword relationship 8532-59f6-df1e-e9c6 70
# inserting keyword relationship 8532-59f6-df1e-e9c6 72
# inserting weapon Power Glaive 3+ 5 -2 1 48aa-7ce4-28b5-ecfa 3 e6c2-f3b2-6d3e-c3d3
# inserting weapon Avenger Shuriken Catapult 3+ 4 -1 1 4599-4e15-ec45-cf8d 3 e6c2-f3b2-6d3e-c3d3
# inserting keyword relationship 4599-4e15-ec45-cf8d 70
# inserting keyword relationship 4599-4e15-ec45-cf8d 71
# inserting weapon Diresword 3+ 4 -2 1 be6b-59d-e826-7321 3 e6c2-f3b2-6d3e-c3d3
# inserting keyword relationship be6b-59d-e826-7321 73
# inserting weapon Power Glaive 3+ 5 -2 1 8350-2117-824b-dbab 3 e6c2-f3b2-6d3e-c3d3
# inserting weapon Close Combat Weapon 3+ 3 0 1 b87d-d22e-cfe5-41ae 2 e6c2-f3b2-6d3e-c3d3
# inserting unit cost e6c2-f3b2-6d3e-c3d3 70 default
# inserting unit cost e6c2-f3b2-6d3e-c3d3 140 greaterThan 5
# inserting unit Eldrad Ulthran  f48e-276e-a997-c90e dfcf-1214-b57-2205
# inserting model 6bf0-37ae-157a-d4d1 Eldrad Ulthran 7" 4 5 6+ 6+ f48e-276e-a997-c90e 1
# inserting weapon Shuriken Pistol 2+ 4 -1 1 b09f-1dc6-5ddb-fe9a 1 f48e-276e-a997-c90e
# inserting keyword relationship b09f-1dc6-5ddb-fe9a 70
# inserting keyword relationship b09f-1dc6-5ddb-fe9a 72
# inserting weapon Staff of Ulthamar and witchblade 2+ 5 -1 2 a27-a636-463e-30a8 3 f48e-276e-a997-c90e
# inserting keyword relationship a27-a636-463e-30a8 82
# inserting keyword relationship a27-a636-463e-30a8 86
# inserting weapon Mind War 2+ 4 -2 D6 6ad4-b734-dfde-3a85 1 f48e-276e-a997-c90e
# inserting keyword Anti-character 4+
# inserting keyword relationship 6ad4-b734-dfde-3a85 90
# inserting keyword relationship 6ad4-b734-dfde-3a85 84
# inserting keyword relationship 6ad4-b734-dfde-3a85 86
# inserting unit cost f48e-276e-a997-c90e 110 default
# inserting unit Falcon  1d83-167-486c-bac4 dfcf-1214-b57-2205
# inserting model ded7-2ee9-84e6-9829 Falcon 14" 9 12 6+ 3+ 1d83-167-486c-bac4 3
# inserting weapon Pulse Laser 3+ 9 -2 D6 a762-6627-e95c-4357 3 1d83-167-486c-bac4
# inserting weapon Wraithbone hull 4+ 6 0 1 8d7e-f15d-38d0-80c 3 1d83-167-486c-bac4
# inserting weapon Twin Shuriken Catapult 3+ 4 -1 1 9fd-813b-bf1f-6fb8 2 1d83-167-486c-bac4
# inserting keyword relationship 9fd-813b-bf1f-6fb8 70
# inserting keyword relationship 9fd-813b-bf1f-6fb8 74
# inserting weapon Shuriken Cannon 3+ 6 -1 2 ead7-c1d5-83b4-532d 3 1d83-167-486c-bac4
# inserting keyword relationship ead7-c1d5-83b4-532d 80
# inserting unit cost 1d83-167-486c-bac4 140 default
# inserting unit Farseer  b2f5-8219-f875-917e dfcf-1214-b57-2205
# inserting model 94a1-c8f3-11ea-5ce2 Farseer 7" 3 4 6+ 6+ b2f5-8219-f875-917e 1
# inserting weapon Shuriken Pistol 2+ 4 -1 1 f5b9-c818-3551-304c 1 b2f5-8219-f875-917e
# inserting keyword relationship f5b9-c818-3551-304c 70
# inserting keyword relationship f5b9-c818-3551-304c 72
# inserting weapon Eldritch Storm 3+ 6 -2 D3 bbcb-fbad-23ee-79e9 D6 b2f5-8219-f875-917e
# inserting keyword relationship bbcb-fbad-23ee-79e9 88
# inserting keyword relationship bbcb-fbad-23ee-79e9 86
# inserting weapon Witchblade 2+ 3 0 2 6679-e605-1314-bac4 2 b2f5-8219-f875-917e
# inserting keyword relationship 6679-e605-1314-bac4 82
# inserting keyword relationship 6679-e605-1314-bac4 86
# inserting weapon Singing Spear 2+ 9 0 3 2d1f-f377-6bc3-40f6 1 b2f5-8219-f875-917e
# inserting keyword relationship 2d1f-f377-6bc3-40f6 70
# inserting keyword relationship 2d1f-f377-6bc3-40f6 86
# inserting weapon Singing Spear 2+ 3 0 3 8cca-f1e9-21d6-87da 2 b2f5-8219-f875-917e
# inserting keyword relationship 8cca-f1e9-21d6-87da 86
# inserting unit cost b2f5-8219-f875-917e 80 default
# inserting unit Farseer Skyrunner  833b-55bc-73be-8862 dfcf-1214-b57-2205
# inserting model 5f18-4793-74a7-b6c2 Farseer Skyrunner 14" 4 5 6+ 3+ 833b-55bc-73be-8862 2
# inserting weapon Witchblade 2+ 3 0 2 aa4c-c850-5606-3153 2 833b-55bc-73be-8862
# inserting keyword relationship aa4c-c850-5606-3153 82
# inserting keyword relationship aa4c-c850-5606-3153 86
# inserting weapon Singing Spear 2+ 9 0 3 a4b8-2ce3-93a2-f98b 1 833b-55bc-73be-8862
# inserting keyword relationship a4b8-2ce3-93a2-f98b 70
# inserting keyword relationship a4b8-2ce3-93a2-f98b 86
# inserting weapon Singing Spear 2+ 3 0 3 938f-d1ee-fb90-c89c 2 833b-55bc-73be-8862
# inserting keyword relationship 938f-d1ee-fb90-c89c 86
# inserting weapon Shuriken Pistol 2+ 4 -1 1 7825-a114-ca5f-1bc2 1 833b-55bc-73be-8862
# inserting keyword relationship 7825-a114-ca5f-1bc2 70
# inserting keyword relationship 7825-a114-ca5f-1bc2 72
# inserting weapon Twin Shuriken Catapult 3+ 4 -1 1 5fa6-19eb-f75e-a41 2 833b-55bc-73be-8862
# inserting keyword relationship 5fa6-19eb-f75e-a41 70
# inserting keyword relationship 5fa6-19eb-f75e-a41 74
# inserting weapon Eldritch Storm 3+ 6 -2 D3 b718-46ea-b550-2352 D6 833b-55bc-73be-8862
# inserting keyword relationship b718-46ea-b550-2352 88
# inserting keyword relationship b718-46ea-b550-2352 86
# inserting unit cost 833b-55bc-73be-8862 90 default
# inserting unit Fire Dragons  5374-9e93-8af2-819e dfcf-1214-b57-2205
# inserting model 73cd-7b92-277e-1865 Fire Dragon 7" 3 1 6+ 3+ 5374-9e93-8af2-819e 1
# inserting model 5e28-5a0c-3b36-e7 Fire Dragon Exarch 7" 3 2 6+ 3+ 5374-9e93-8af2-819e 1
# inserting weapon Dragon Fusion Gun 3+ 9 -4 D6 6df9-6f5a-1abe-209b 1 5374-9e93-8af2-819e
# inserting keyword relationship 6df9-6f5a-1abe-209b 70
# inserting keyword relationship 6df9-6f5a-1abe-209b 76
# inserting weapon Close combat weapon 3+ 3 0 1 3749-23a8-3c4d-8d10 2 5374-9e93-8af2-819e
# inserting weapon Dragon Fusion Gun 3+ 9 -4 D6 3667-ae74-55df-50a1 1 5374-9e93-8af2-819e
# inserting keyword relationship 3667-ae74-55df-50a1 70
# inserting keyword relationship 3667-ae74-55df-50a1 76
# inserting weapon Dragon's Breath Flamer N/A 6 -1 1 66f3-4118-b9b2-ed3 D6 5374-9e93-8af2-819e
# inserting keyword relationship 66f3-4118-b9b2-ed3 87
# inserting keyword relationship 66f3-4118-b9b2-ed3 78
# inserting weapon Firepike 3+ 12 -4 D6 5fd8-5b1f-42b8-e8f3 1 5374-9e93-8af2-819e
# inserting keyword relationship 5fd8-5b1f-42b8-e8f3 76
# inserting weapon Close combat weapon 3+ 3 0 1 747c-4a89-2bae-ece0 2 5374-9e93-8af2-819e
# inserting unit cost 5374-9e93-8af2-819e 85 default
# inserting unit cost 5374-9e93-8af2-819e 170 greaterThan 5
# inserting unit Fire Prism  9940-a69b-682e-ccf4 dfcf-1214-b57-2205
# inserting model 8b96-e5ef-3632-6f56 Fire Prism 14" 9 12 6+ 3+ 9940-a69b-682e-ccf4 3
# inserting weapon Twin Shuriken Catapult 3+ 4 -1 1 638d-416f-93be-165d 2 9940-a69b-682e-ccf4
# inserting keyword relationship 638d-416f-93be-165d 70
# inserting keyword relationship 638d-416f-93be-165d 74
# inserting weapon Shuriken Cannon 3+ 6 -1 2 3a01-4ed4-c367-f53b 3 9940-a69b-682e-ccf4
# inserting keyword relationship 3a01-4ed4-c367-f53b 80
# inserting weapon ➤ Prism Cannon - dispersed pulse 3+ 6 -1 2 cf51-83c3-5e6b-9440 2D6 9940-a69b-682e-ccf4
# inserting keyword relationship cf51-83c3-5e6b-9440 88
# inserting weapon ➤ Prism Cannon - focused lances 3+ 18 -4 6 9ca0-fcce-98eb-7efc 2 9940-a69b-682e-ccf4
# inserting keyword Linked Fire
# inserting keyword relationship 9ca0-fcce-98eb-7efc 91
# inserting weapon Wraithbone Hull 4+ 6 0 1 af8b-71f6-6396-224 3 9940-a69b-682e-ccf4
# inserting unit cost 9940-a69b-682e-ccf4 180 default
# inserting unit Fuegan  9262-3993-1368-be5a dfcf-1214-b57-2205
# inserting model 2424-22f8-ea6b-10e3 Fuegan 7" 3 5 6+ 2+ 9262-3993-1368-be5a 1
# inserting weapon ➤ Searsong - Beam 2+ 8 -3 2 7ea5-ac5a-d143-9887 3 9262-3993-1368-be5a
# inserting keyword relationship 7ea5-ac5a-d143-9887 81
# inserting weapon ➤ Searsong - Lance 2+ 14 -4 D6 ce26-12a0-2593-bcd7 1 9262-3993-1368-be5a
# inserting keyword Melta 6
# inserting keyword relationship ce26-12a0-2593-bcd7 92
# inserting weapon The Fire Axe 2+ 5 -4 3 b221-68c3-7f95-b3d 6 9262-3993-1368-be5a
# inserting unit cost 9262-3993-1368-be5a 130 default
# inserting unit Guardian Defenders  e78a-4442-4ed2-66bf dfcf-1214-b57-2205
# inserting model d3d1-268f-e122-ba51 Guardian Defender 7" 3 1 6+ 4+ e78a-4442-4ed2-66bf 2
# inserting model 8315-beb0-9d5-f770 Heavy Weapon Platform 7" 3 2 6+ 4+ e78a-4442-4ed2-66bf 0
# inserting weapon Shuriken Catapult 3+ 4 -1 1 2e20-80c3-da0b-b8d8 2 e78a-4442-4ed2-66bf
# inserting keyword relationship 2e20-80c3-da0b-b8d8 70
# inserting weapon Close Combat Weapon 3+ 3 0 1 f1ef-88ac-e523-57ab 1 e78a-4442-4ed2-66bf
# inserting unit cost e78a-4442-4ed2-66bf 100 default
# inserting unit Hemlock Wraithfighter  551b-900c-3681-8f11 dfcf-1214-b57-2205
# inserting model 5ac0-a31b-ae7b-a8c6 Hemlock Wraithfighter 20+" 8 12 6+ 3+ 551b-900c-3681-8f11 0
# inserting weapon Wraithbone Hull 4+ 6 0 1 1037-8981-d5d1-7918 3 551b-900c-3681-8f11
# inserting weapon Heavy D-Scythe 4+ 12 -4 2 a9ec-e576-4eb4-a235 D6 551b-900c-3681-8f11
# inserting keyword relationship a9ec-e576-4eb4-a235 88
# inserting unit cost 551b-900c-3681-8f11 155 default
# inserting unit Howling Banshees  7fcb-9262-474a-7cec dfcf-1214-b57-2205
# inserting model 5c4c-e8c5-457-96e4 Howling Banshee Exarch 8" 3 2 6+ 4+ 7fcb-9262-474a-7cec 1
# inserting model 7923-bc16-c44c-a6fc Howling Banshee 8" 3 1 6+ 4+ 7fcb-9262-474a-7cec 1
# inserting weapon Banshee Blade 3+ 4 -3 1 5aaa-b9cc-8c47-ea1c 3 7fcb-9262-474a-7cec
# inserting weapon Shuriken Pistol 3+ 4 -1 1 7c68-3954-ece2-1d37 1 7fcb-9262-474a-7cec
# inserting keyword relationship 7c68-3954-ece2-1d37 70
# inserting keyword relationship 7c68-3954-ece2-1d37 72
# inserting weapon Shuriken Pistol 3+ 4 -1 1 ca84-41b1-af9c-e557 1 7fcb-9262-474a-7cec
# inserting keyword relationship ca84-41b1-af9c-e557 70
# inserting keyword relationship ca84-41b1-af9c-e557 72
# inserting weapon Executioner 3+ 5 -2 2 1551-6e4b-ef24-638d 4 7fcb-9262-474a-7cec
# inserting weapon Shuriken Pistol 3+ 4 -1 1 a068-a0e7-d854-6ade 1 7fcb-9262-474a-7cec
# inserting keyword relationship a068-a0e7-d854-6ade 70
# inserting keyword relationship a068-a0e7-d854-6ade 72
# inserting weapon Triskele 3+ 3 -2 1 13aa-5a19-c623-1e70 5 7fcb-9262-474a-7cec
# inserting weapon Triskele 3+ 4 -2 1 dd10-c643-38b7-5d10 3 7fcb-9262-474a-7cec
# inserting keyword relationship dd10-c643-38b7-5d10 70
# inserting weapon Mirrorswords 3+ 4 -3 1 a165-3b82-7ca9-640c 6 7fcb-9262-474a-7cec
# inserting weapon Banshee Blade 3+ 4 -3 1 3985-7b92-7cf0-6f3d 3 7fcb-9262-474a-7cec
# inserting weapon Shuriken Pistol 3+ 4 -1 1 998d-b0f6-476d-8518 1 7fcb-9262-474a-7cec
# inserting keyword relationship 998d-b0f6-476d-8518 70
# inserting keyword relationship 998d-b0f6-476d-8518 72
# inserting unit cost 7fcb-9262-474a-7cec 70 default
# inserting unit cost 7fcb-9262-474a-7cec 140 greaterThan 5
# inserting unit Illic Nightspear  2713-f82d-5189-d5de dfcf-1214-b57-2205
# inserting model 9385-f6cf-dcfa-a665 Illic Nightspear 7" 3 3 6+ 5+ 2713-f82d-5189-d5de 1
# inserting weapon Shuriken Pistol 2+ 4 -1 1 c9fb-5944-b174-dd3f 1 2713-f82d-5189-d5de
# inserting keyword relationship c9fb-5944-b174-dd3f 70
# inserting keyword relationship c9fb-5944-b174-dd3f 72
# inserting weapon Voidbringer 2+ 6 -3 3 550b-1ce3-d0bf-27b8 1 2713-f82d-5189-d5de
# inserting keyword relationship 550b-1ce3-d0bf-27b8 73
# inserting keyword relationship 550b-1ce3-d0bf-27b8 77
# inserting keyword relationship 550b-1ce3-d0bf-27b8 84
# inserting weapon Aeldari power sword 2+ 4 -2 1 8c4d-a098-f621-aec8 4 2713-f82d-5189-d5de
# inserting unit cost 2713-f82d-5189-d5de 70 default
# inserting unit Jain Zar  77f9-e8de-225f-9e68 dfcf-1214-b57-2205
# inserting model 21ec-f32a-ec08-dfd6 Jain Zar 8" 3 5 6+ 2+ 77f9-e8de-225f-9e68 1
# inserting weapon Silent Death 2+ 6 -2 1 784d-1c56-2d7a-4806 6 77f9-e8de-225f-9e68
# inserting keyword relationship 784d-1c56-2d7a-4806 70
# inserting weapon ➤ The Blade of Destruction - Strike 2+ 6 -3 2 935c-84d6-da62-862d 6 77f9-e8de-225f-9e68
# inserting weapon ➤ The Blade of Destruction - Sweep 2+ 4 -3 1 df6f-20fd-ec40-f67e 12 77f9-e8de-225f-9e68
# inserting unit cost 77f9-e8de-225f-9e68 105 default
# inserting unit Karandras  c9ed-d190-419c-78d3 dfcf-1214-b57-2205
# inserting model ca7f-fb3e-1746-b2c7 Karandras 7" 3 5 6+ 2+ c9ed-d190-419c-78d3 1
# inserting weapon Arhra's Bane 2+ 5 -1 2 482c-616a-50c9-b796 2 c9ed-d190-419c-78d3
# inserting keyword relationship 482c-616a-50c9-b796 70
# inserting keyword relationship 482c-616a-50c9-b796 72
# inserting weapon Arhra's Bane 2+ 8 -3 2 312e-6367-d553-849a 5 c9ed-d190-419c-78d3
# inserting keyword relationship 312e-6367-d553-849a 80
# inserting weapon Isirmathil 2+ 6 -1 1 804f-8650-c15a-2af8 8 c9ed-d190-419c-78d3
# inserting keyword relationship 804f-8650-c15a-2af8 80
# inserting unit cost c9ed-d190-419c-78d3 100 default
# inserting unit Maugan Ra  6f18-95b7-2662-8925 dfcf-1214-b57-2205
# inserting model c1cd-6cb9-8a22-857e Maugan Ra 7" 3 5 6+ 2+ 6f18-95b7-2662-8925 1
# inserting weapon The Maugetar 2+ 7 -1 2 8919-d0aa-fab9-ac56 6 6f18-95b7-2662-8925
# inserting keyword relationship 8919-d0aa-fab9-ac56 73
# inserting keyword relationship 8919-d0aa-fab9-ac56 87
# inserting weapon The Maugetar 2+ 6 -2 2 378-72f-528c-efe7 5 6f18-95b7-2662-8925
# inserting unit cost 6f18-95b7-2662-8925 130 default
# inserting unit Night Spinner  908a-fc2b-5a53-599f dfcf-1214-b57-2205
# inserting model 5687-3aad-8a6b-979e Night Spinner 14" 9 12 6+ 3+ 908a-fc2b-5a53-599f 3
# inserting weapon Twin Shuriken Catapult 3+ 4 -1 1 dda6-6cce-7d25-af4 2 908a-fc2b-5a53-599f
# inserting keyword relationship dda6-6cce-7d25-af4 70
# inserting keyword relationship dda6-6cce-7d25-af4 74
# inserting weapon Shuriken Cannon 3+ 6 -1 2 3983-a8e9-2d16-19b9 3 908a-fc2b-5a53-599f
# inserting keyword relationship 3983-a8e9-2d16-19b9 80
# inserting weapon Doomweaver 3+ 7 0 2 7854-1000-7c9e-3e6a D6+3 908a-fc2b-5a53-599f
# inserting keyword relationship 7854-1000-7c9e-3e6a 88
# inserting keyword relationship 7854-1000-7c9e-3e6a 73
# inserting keyword relationship 7854-1000-7c9e-3e6a 89
# inserting keyword relationship 7854-1000-7c9e-3e6a 74
# inserting weapon Wraithbone Hull 4+ 6 0 1 b86a-9b1f-81be-b461 3 908a-fc2b-5a53-599f
# inserting unit cost 908a-fc2b-5a53-599f 210 default
# inserting unit Prince Yriel  1fbf-55d9-5ca8-4e9e dfcf-1214-b57-2205
# inserting model 1679-939b-2f47-aad Prince Yriel 7" 3 4 6+ 3+ 1fbf-55d9-5ca8-4e9e 1
# inserting weapon The Eye of Wrath 2+ 6 -3 2 a3a9-4f5a-c48f-d7aa 1 1fbf-55d9-5ca8-4e9e
# inserting keyword relationship a3a9-4f5a-c48f-d7aa 70
# inserting weapon The Spear of Twilight 2+ 6 -3 3 8fff-8bf0-b11a-866c 5 1fbf-55d9-5ca8-4e9e
# inserting unit cost 1fbf-55d9-5ca8-4e9e 100 default
# inserting unit Rangers  b98b-701f-9c0c-5437 dfcf-1214-b57-2205
# inserting model 2fbe-576e-b572-bdd8 Rangers 7" 3 1 6+ 5+ b98b-701f-9c0c-5437 1
# inserting weapon Ranger long rifle 3+ 4 -1 2 7dfc-a9a1-aa3-5a1f 1 b98b-701f-9c0c-5437
# inserting keyword relationship 7dfc-a9a1-aa3-5a1f 77
# inserting keyword relationship 7dfc-a9a1-aa3-5a1f 84
# inserting weapon Shuriken Pistol 2+ 4 -1 1 2316-3676-cb4b-bdb6 1 b98b-701f-9c0c-5437
# inserting keyword relationship 2316-3676-cb4b-bdb6 70
# inserting keyword relationship 2316-3676-cb4b-bdb6 72
# inserting weapon Close Combat Weapon 3+ 3 0 1 c3fc-36dc-8595-3b71 1 b98b-701f-9c0c-5437
# inserting unit cost b98b-701f-9c0c-5437 55 default
# inserting unit cost b98b-701f-9c0c-5437 110 greaterThan 5
# inserting unit Shadowseer  8c34-52ba-cbd0-9ca4 dfcf-1214-b57-2205
# inserting model 33ad-85bd-3ae4-7f96 Shadowseer 8" 3 4 6+ 6+ 8c34-52ba-cbd0-9ca4 1
# inserting weapon Miststave 2+ 5 -1 D3 e652-815c-4106-690d 4 8c34-52ba-cbd0-9ca4
# inserting keyword relationship e652-815c-4106-690d 86
# inserting weapon Shuriken Pistol 2+ 4 -1 1 aab5-8360-a50-d395 1 8c34-52ba-cbd0-9ca4
# inserting keyword relationship aab5-8360-a50-d395 70
# inserting keyword relationship aab5-8360-a50-d395 72
# inserting weapon Neuro Disruptor 2+ 4 0 1 ebc7-b59c-5e9-3df5 1 8c34-52ba-cbd0-9ca4
# inserting keyword relationship ebc7-b59c-5e9-3df5 82
# inserting keyword relationship ebc7-b59c-5e9-3df5 70
# inserting keyword relationship ebc7-b59c-5e9-3df5 72
# inserting unit cost 8c34-52ba-cbd0-9ca4 60 default
# inserting unit Shining Spears  433-faed-ea62-c531 dfcf-1214-b57-2205
# inserting model 93be-1105-45e3-2ed4 Shining Spear 14" 4 2 6+ 3+ 433-faed-ea62-c531 2
# inserting model c655-a241-b8dc-fffb Shining Spear Exarch 14" 4 3 6+ 3+ 433-faed-ea62-c531 2
# inserting weapon Twin Shuriken Catapult 3+ 4 -1 1 8ca9-29c4-3524-9645 2 433-faed-ea62-c531
# inserting keyword relationship 8ca9-29c4-3524-9645 70
# inserting keyword relationship 8ca9-29c4-3524-9645 74
# inserting weapon Laser Lance 3+ 6 -2 2 887c-9a9b-953b-90bc 1 433-faed-ea62-c531
# inserting keyword relationship 887c-9a9b-953b-90bc 70
# inserting weapon Laser Lance 3+ 4 -2 2 a6d6-73e7-abae-781f 3 433-faed-ea62-c531
# inserting keyword relationship a6d6-73e7-abae-781f 75
# inserting weapon Laser Lance 3+ 6 -2 2 9a2-c23c-f317-667f 1 433-faed-ea62-c531
# inserting keyword relationship 9a2-c23c-f317-667f 70
# inserting weapon Laser Lance 3+ 4 -2 2 11f5-daff-8b77-c832 3 433-faed-ea62-c531
# inserting keyword relationship 11f5-daff-8b77-c832 75
# inserting weapon Paragon Sabre 3+ 4 -2 2 887e-1f12-6b8f-7068 6 433-faed-ea62-c531
# inserting weapon Star Lance 2+ 9 -3 2 b413-75c2-6a63-93b4 1 433-faed-ea62-c531
# inserting keyword relationship b413-75c2-6a63-93b4 70
# inserting weapon Star Lance 2+ 4 -3 2 cde7-e488-f8e3-b8c 4 433-faed-ea62-c531
# inserting keyword relationship cde7-e488-f8e3-b8c 75
# inserting weapon Twin Shuriken Catapult 3+ 4 -1 1 c6b0-54d2-9464-d1d6 2 433-faed-ea62-c531
# inserting keyword relationship c6b0-54d2-9464-d1d6 70
# inserting keyword relationship c6b0-54d2-9464-d1d6 74
# inserting weapon Shuriken Cannon 3+ 6 -1 2 7478-1c4f-2ae4-e20b 3 433-faed-ea62-c531
# inserting keyword relationship 7478-1c4f-2ae4-e20b 80
# inserting unit cost 433-faed-ea62-c531 100 default
# inserting unit cost 433-faed-ea62-c531 200 greaterThan 3
# inserting unit Shroud Runners  c1ff-dc11-9853-e3e3 dfcf-1214-b57-2205
# inserting model 3852-9c9f-eaef-276a Shroud Runner 14" 4 3 6+ 4+ c1ff-dc11-9853-e3e3 2
# inserting weapon Ranger long rifle 3+ 4 -1 2 aa62-f94b-d7ff-6425 1 c1ff-dc11-9853-e3e3
# inserting keyword relationship aa62-f94b-d7ff-6425 77
# inserting keyword relationship aa62-f94b-d7ff-6425 84
# inserting weapon Shuriken Pistol 2+ 4 -1 1 1232-fd9d-dec7-2653 1 c1ff-dc11-9853-e3e3
# inserting keyword relationship 1232-fd9d-dec7-2653 70
# inserting keyword relationship 1232-fd9d-dec7-2653 72
# inserting weapon Close Combat Weapon 3+ 3 0 1 eb7-6e5e-c58f-8504 1 c1ff-dc11-9853-e3e3
# inserting weapon Scatter Laser 3+ 5 0 1 96bd-6f95-6d55-2d6b 6 c1ff-dc11-9853-e3e3
# inserting unit cost c1ff-dc11-9853-e3e3 80 default
# inserting unit cost c1ff-dc11-9853-e3e3 160 greaterThan 3
# inserting unit Skyweavers  9270-4b93-ca59-f3ed dfcf-1214-b57-2205
# inserting model d25d-2a63-d6f2-b7 Skyweaver 14" 4 3 6+ 4+ 9270-4b93-ca59-f3ed 2
# inserting weapon Skyweaver Haywire Cannon 3+ 3 -1 3 4bd2-ee10-c292-3d3c 2 9270-4b93-ca59-f3ed
# inserting keyword Anti-Vehicle 4+
# inserting keyword relationship 4bd2-ee10-c292-3d3c 93
# inserting keyword relationship 4bd2-ee10-c292-3d3c 73
# inserting weapon Star Bolas 3+ 7 -2 2 cdf6-7b38-a2ce-2ad8 D3 9270-4b93-ca59-f3ed
# inserting weapon Zephyrglaive 3+ 5 -1 2 f8f-d5dd-e0cf-5cec 4 9270-4b93-ca59-f3ed
# inserting weapon Close Combat Weapon 3+ 3 0 1 c7ce-9672-521-696 4 9270-4b93-ca59-f3ed
# inserting unit cost 9270-4b93-ca59-f3ed 95 default
# inserting unit cost 9270-4b93-ca59-f3ed 190 greaterThan 2
# inserting unit Solitaire  f88f-60c5-3daf-3d2f dfcf-1214-b57-2205
# inserting model 8c5f-427-b103-ee0c Solitaire 12" 3 3 6+ 6+ f88f-60c5-3daf-3d2f 1
# inserting weapon Solitaire Weapons 2+ 6 -2 2 3daf-5355-b7ea-b291 9 f88f-60c5-3daf-3d2f
# inserting keyword relationship 3daf-5355-b7ea-b291 84
# inserting unit cost f88f-60c5-3daf-3d2f 115 default
# inserting unit Spiritseer  e53b-7d09-eb7c-c6c7 dfcf-1214-b57-2205
# inserting model 976c-aa8a-1efc-10b4 Spiritseer 7" 3 3 6+ 6+ e53b-7d09-eb7c-c6c7 1
# inserting weapon Shuriken Pistol 2+ 4 -1 1 39db-20fd-3098-8bcc 1 e53b-7d09-eb7c-c6c7
# inserting keyword relationship 39db-20fd-3098-8bcc 70
# inserting keyword relationship 39db-20fd-3098-8bcc 72
# inserting weapon Witch Staff 2+ 3 0 D3 ea0d-c143-4e2d-64b3 2 e53b-7d09-eb7c-c6c7
# inserting keyword relationship ea0d-c143-4e2d-64b3 82
# inserting keyword relationship ea0d-c143-4e2d-64b3 86
# inserting unit cost e53b-7d09-eb7c-c6c7 65 default
# inserting unit Starweaver  854b-f8e-28fa-8c24 dfcf-1214-b57-2205
# inserting model f7-500d-52ff-e195 Starweaver 14" 6 6 6+ 4+ 854b-f8e-28fa-8c24 1
# inserting weapon Close Combat Weapon 3+ 3 0 1 f79b-a7f3-a0af-4461 4 854b-f8e-28fa-8c24
# inserting unit cost 854b-f8e-28fa-8c24 80 default
# inserting unit Storm Guardians  5452-c4a7-59fb-f05c dfcf-1214-b57-2205
# inserting model 309e-a276-263a-56ae Storm Guardian 7" 3 1 6+ 4+ 5452-c4a7-59fb-f05c 2
# inserting model daae-16aa-68b5-1291 Serpent's Scale Platform 7" 3 2 6+ 4+ 5452-c4a7-59fb-f05c 0
# inserting weapon Guardian Combat Weapon 3+ 3 0 1 fc92-e7a4-3b82-2b47 2 5452-c4a7-59fb-f05c
# inserting weapon Shuriken Pistol 3+ 4 -1 1 895f-b473-f91d-5194 1 5452-c4a7-59fb-f05c
# inserting keyword relationship 895f-b473-f91d-5194 70
# inserting keyword relationship 895f-b473-f91d-5194 72
# inserting weapon Aeldari Flamer N/A 4 0 1 9dcc-347-c99f-3db6 D6 5452-c4a7-59fb-f05c
# inserting keyword relationship 9dcc-347-c99f-3db6 70
# inserting keyword relationship 9dcc-347-c99f-3db6 87
# inserting keyword relationship 9dcc-347-c99f-3db6 78
# inserting weapon Guardian Fusion Gun 3+ 8 -4 D6 6ff1-3647-9b24-5187 1 5452-c4a7-59fb-f05c
# inserting keyword relationship 6ff1-3647-9b24-5187 70
# inserting keyword relationship 6ff1-3647-9b24-5187 79
# inserting weapon Shuriken Pistol 3+ 4 -1 1 b291-5639-46fb-c062 1 5452-c4a7-59fb-f05c
# inserting keyword relationship b291-5639-46fb-c062 70
# inserting keyword relationship b291-5639-46fb-c062 72
# inserting weapon Aeldari power sword 3+ 4 -2 1 e38d-9485-ec34-5c0b 2 5452-c4a7-59fb-f05c
# inserting unit cost 5452-c4a7-59fb-f05c 100 default
# inserting unit Striking Scorpions  c90f-a8e5-6afa-eb91 dfcf-1214-b57-2205
# inserting model b55c-1f44-b91a-1b3a Striking Scorpion 7" 3 1 6+ 3+ c90f-a8e5-6afa-eb91 1
# inserting model f2f3-1317-53b8-fd5c Striking Scorpion Exarch 7" 3 2 6+ 3+ c90f-a8e5-6afa-eb91 1
# inserting weapon Scorpion chainsword 3+ 4 0 1 21dd-de86-1ab8-d23 4 c90f-a8e5-6afa-eb91
# inserting keyword relationship 21dd-de86-1ab8-d23 80
# inserting weapon Shuriken pistol 3+ 4 -1 1 af50-18f0-aa1f-3d40 1 c90f-a8e5-6afa-eb91
# inserting keyword relationship af50-18f0-aa1f-3d40 70
# inserting keyword relationship af50-18f0-aa1f-3d40 72
# inserting weapon Scorpion chainsword 3+ 4 0 1 8a52-d617-a4d5-60f2 4 c90f-a8e5-6afa-eb91
# inserting keyword relationship 8a52-d617-a4d5-60f2 80
# inserting weapon Shuriken pistol 3+ 4 -1 1 92c2-e86f-17f2-6dc7 1 c90f-a8e5-6afa-eb91
# inserting keyword relationship 92c2-e86f-17f2-6dc7 70
# inserting keyword relationship 92c2-e86f-17f2-6dc7 72
# inserting weapon Scorpion's claw 3+ 4 -1 1 9cdc-41e8-536a-8675 2 c90f-a8e5-6afa-eb91
# inserting keyword relationship 9cdc-41e8-536a-8675 70
# inserting keyword relationship 9cdc-41e8-536a-8675 72
# inserting weapon Scorpion's claw 4+ 8 -2 2 edf7-1ef5-cefc-9c91 4 c90f-a8e5-6afa-eb91
# inserting keyword relationship edf7-1ef5-cefc-9c91 80
# inserting weapon Scorpion chainsword 3+ 4 0 1 4e49-d71c-a4b0-2b22 4 c90f-a8e5-6afa-eb91
# inserting keyword relationship 4e49-d71c-a4b0-2b22 80
# inserting weapon Biting blade 3+ 5 -1 2 eb92-2e30-8ab8-a987 5 c90f-a8e5-6afa-eb91
# inserting keyword relationship eb92-2e30-8ab8-a987 80
# inserting unit cost c90f-a8e5-6afa-eb91 65 default
# inserting unit cost c90f-a8e5-6afa-eb91 130 greaterThan 5
# inserting unit Support Weapons  82ac-7d93-df55-5504 dfcf-1214-b57-2205
# inserting model 5711-ae0b-3bf1-5be7 Support Weapons 3" 6 5 6+ 4+ 82ac-7d93-df55-5504 1
# inserting weapon Shadow weaver 3+ 6 0 1 d3cc-2057-4c39-d51d D6+2 82ac-7d93-df55-5504
# inserting keyword relationship d3cc-2057-4c39-d51d 88
# inserting keyword relationship d3cc-2057-4c39-d51d 73
# inserting keyword relationship d3cc-2057-4c39-d51d 77
# inserting keyword relationship d3cc-2057-4c39-d51d 89
# inserting weapon D-cannon 3+ 16 -4 D6+2 d9b1-ed33-1704-82b D3 82ac-7d93-df55-5504
# inserting keyword relationship d9b1-ed33-1704-82b 88
# inserting keyword relationship d9b1-ed33-1704-82b 73
# inserting keyword relationship d9b1-ed33-1704-82b 77
# inserting keyword relationship d9b1-ed33-1704-82b 89
# inserting weapon Vibro Cannon 3+ 8 -1 2 c672-7257-4e93-1c05 D6 82ac-7d93-df55-5504
# inserting keyword relationship c672-7257-4e93-1c05 77
# inserting weapon Close Combat Weapon 3+ 3 0 1 3537-9388-7bb2-9696 2 82ac-7d93-df55-5504
# inserting weapon Shuriken Catapult 3+ 4 -1 1 7fe1-79a6-355d-ddf1 2 82ac-7d93-df55-5504
# inserting keyword relationship 7fe1-79a6-355d-ddf1 70
# inserting unit cost 82ac-7d93-df55-5504 135 default
# inserting unit Swooping Hawks  240f-70a4-7ba7-a538 dfcf-1214-b57-2205
# inserting model 6bd1-ad51-9907-7cbe Swooping Hawk 14" 3 1 6+ 4+ 240f-70a4-7ba7-a538 1
# inserting model 3252-2e6d-4345-da6e Swooping Hawk Exarch 14" 3 2 6+ 4+ 240f-70a4-7ba7-a538 1
# inserting weapon Lasblaster 3+ 4 0 1 52ce-81fc-4728-3571 4 240f-70a4-7ba7-a538
# inserting keyword relationship 52ce-81fc-4728-3571 70
# inserting keyword relationship 52ce-81fc-4728-3571 71
# inserting weapon Close Combat Weapon 3+ 3 0 1 7445-590-a861-db6c 2 240f-70a4-7ba7-a538
# inserting weapon Aeldari Power Sword 3+ 4 -2 1 d5d4-cc2f-5cdc-77d3 3 240f-70a4-7ba7-a538
# inserting weapon Close Combat Weapon 3+ 3 0 1 7e3f-7bd-4259-432b 2 240f-70a4-7ba7-a538
# inserting weapon Lasblaster 3+ 4 0 1 6d45-6c86-9ef7-9b63 4 240f-70a4-7ba7-a538
# inserting keyword relationship 6d45-6c86-9ef7-9b63 70
# inserting keyword relationship 6d45-6c86-9ef7-9b63 71
# inserting weapon Hawk's Talon 3+ 5 0 1 77ab-e47f-90dd-3471 4 240f-70a4-7ba7-a538
# inserting keyword relationship 77ab-e47f-90dd-3471 70
# inserting keyword relationship 77ab-e47f-90dd-3471 71
# inserting unit cost 240f-70a4-7ba7-a538 80 default
# inserting unit cost 240f-70a4-7ba7-a538 160 greaterThan 5
# inserting unit The Visarch  dd79-c2fe-59d6-d2 dfcf-1214-b57-2205
# inserting model 3e4-3577-5a37-5f19 The Visarch 8" 3 5 6+ 2+ dd79-c2fe-59d6-d2 1
# inserting weapon Asu-var, The Sword of Silent Screams 2+ 5 -4 2 32e0-5d13-656a-219e 5 dd79-c2fe-59d6-d2
# inserting keyword relationship 32e0-5d13-656a-219e 84
# inserting unit cost dd79-c2fe-59d6-d2 90 default
# inserting unit The Yncarne  68fb-4b6f-2bf8-7105 dfcf-1214-b57-2205
# inserting model 3912-ccf-2485-65df The Yncarne 10" 10 12 6+ 2+ 68fb-4b6f-2bf8-7105 3
# inserting weapon ➤ Vilith-zhar, the Sword of Souls - Strike 2+ 12 -4 D6+1 8ced-4b6-1340-a7d2 5 68fb-4b6f-2bf8-7105
# inserting weapon ➤ Vilith-zhar, the Sword of Souls - Sweep 2+ 6 -4 1 70c5-69cc-1005-efca 10 68fb-4b6f-2bf8-7105
# inserting weapon Swirling soul energy N/A 7 -1 D3 7228-c0ff-4629-1b0 D6+3 68fb-4b6f-2bf8-7105
# inserting keyword relationship 7228-c0ff-4629-1b0 87
# inserting keyword relationship 7228-c0ff-4629-1b0 86
# inserting keyword relationship 7228-c0ff-4629-1b0 78
# inserting unit cost 68fb-4b6f-2bf8-7105 350 default
# inserting unit Troupe  dac1-6a7f-a06a-82cf dfcf-1214-b57-2205
# inserting model 42ad-7f55-e574-2e1b Troupe 8" 3 1 6+ 6+ dac1-6a7f-a06a-82cf 1
# inserting weapon Harlequin's Blade 3+ 3 0 1 2a14-b0fe-c220-44ee 5 dac1-6a7f-a06a-82cf
# inserting weapon Harlequin's Special Weapon 3+ 4 -1 1 e975-e852-f7b6-96a9 4 dac1-6a7f-a06a-82cf
# inserting weapon Aeldari power sword 3+ 4 -2 1 7513-6efd-dee-3eb7 5 dac1-6a7f-a06a-82cf
# inserting weapon Shuriken Pistol 3+ 4 -1 1 2000-a049-9c43-224 1 dac1-6a7f-a06a-82cf
# inserting keyword relationship 2000-a049-9c43-224 70
# inserting keyword relationship 2000-a049-9c43-224 72
# inserting weapon Shuriken Pistol 3+ 4 -1 1 f143-ae91-cefd-af24 1 dac1-6a7f-a06a-82cf
# inserting keyword relationship f143-ae91-cefd-af24 70
# inserting keyword relationship f143-ae91-cefd-af24 72
# inserting weapon Harlequin's Blade 3+ 3 0 1 e495-6302-c5b5-ec3d 5 dac1-6a7f-a06a-82cf
# inserting weapon Shuriken Pistol 3+ 4 -1 1 14e2-d7d2-f6ed-d34f 1 dac1-6a7f-a06a-82cf
# inserting keyword relationship 14e2-d7d2-f6ed-d34f 70
# inserting keyword relationship 14e2-d7d2-f6ed-d34f 72
# inserting weapon Harlequin's Special Weapon 3+ 4 -1 1 d6de-c4c2-c27c-29fb 4 dac1-6a7f-a06a-82cf
# inserting weapon Harlequin's Blade 3+ 3 0 1 a801-a5a9-ad3f-12f4 5 dac1-6a7f-a06a-82cf
# inserting weapon Harlequin's Special Weapon 3+ 4 -1 1 1240-a2c3-122a-3764 4 dac1-6a7f-a06a-82cf
# inserting weapon Harlequin's Blade 3+ 3 0 1 3864-d328-80d-c9aa 5 dac1-6a7f-a06a-82cf
# inserting weapon Harlequin's Special Weapon 3+ 4 -1 1 9b33-ebbd-4569-2ab3 4 dac1-6a7f-a06a-82cf
# inserting unit cost dac1-6a7f-a06a-82cf 75 default
# inserting unit cost dac1-6a7f-a06a-82cf 180 equalTo 12
# inserting unit cost dac1-6a7f-a06a-82cf 165 greaterThan 6
# inserting unit cost dac1-6a7f-a06a-82cf 165 lessThan 12
# inserting unit cost dac1-6a7f-a06a-82cf 90 equalTo 6
# inserting unit Troupe Master  dada-b81b-37bd-1f3b dfcf-1214-b57-2205
# inserting model 59bd-21b9-e06f-7475 Troupe Master 8" 3 4 6+ 6+ dada-b81b-37bd-1f3b 1
# inserting weapon Shuriken Pistol 2+ 4 -1 1 fd90-76d2-5529-5fd4 1 dada-b81b-37bd-1f3b
# inserting keyword relationship fd90-76d2-5529-5fd4 70
# inserting keyword relationship fd90-76d2-5529-5fd4 72
# inserting weapon Fusion Pistol 2+ 8 -4 D3 c28-58c8-c736-43fd 1 dada-b81b-37bd-1f3b
# inserting keyword relationship c28-58c8-c736-43fd 70
# inserting keyword relationship c28-58c8-c736-43fd 79
# ...
# inserting weapon Bio-plasma 4+ 7 -2 1 c935-c179-a028-dbb7 D3 9efd-5564-f0f5-21ea
# inserting keyword relationship c935-c179-a028-dbb7 70
# inserting keyword relationship c935-c179-a028-dbb7 88
# inserting weapon Spine Banks 4+ 5 0 1 7ed1-7546-77ee-12e7 5 9efd-5564-f0f5-21ea
# inserting keyword relationship 7ed1-7546-77ee-12e7 70
# inserting weapon Xenos Claws and Teeth 4+ 6 0 1 5ec-2d5f-be85-c1d4 4 9efd-5564-f0f5-21ea
# inserting unit cost 9efd-5564-f0f5-21ea 125 default
# inserting unit Screamer-killer  8e53-d4a-a69f-e71d b984-7317-81cc-20f
# inserting model f4e3-fe83-64d3-1971 Screamer-killer 8" 9 10 8+ 2+ 8e53-d4a-a69f-e71d 3
# inserting weapon Bio-plasmic Scream 4+ 8 -2 1 8d0d-36cd-1ed0-fbb8 D6+3 8e53-d4a-a69f-e71d
# inserting keyword relationship 8d0d-36cd-1ed0-fbb8 70
# inserting keyword relationship 8d0d-36cd-1ed0-fbb8 88
# inserting weapon Screamer-killer Talons 3+ 10 -2 3 7492-4e75-30e6-8c14 10 8e53-d4a-a69f-e71d
# inserting unit cost 8e53-d4a-a69f-e71d 145 default
# inserting unit Hive Guard  ac7a-2560-c083-45b8 b984-7317-81cc-20f
# inserting model 1791-1b63-ac76-ff4f Hive Guard 6" 7 4 8+ 3+ ac7a-2560-c083-45b8 1
# inserting model 2304-d32a-afa8-ebb1 Hive Guard 6" 7 4 8+ 3+ ac7a-2560-c083-45b8 1
# inserting weapon Xenos Claws and Teeth 4+ 5 0 1 eb70-9b6b-6bfd-e4bc 3 ac7a-2560-c083-45b8
# inserting weapon Shockcannon 3+ 7 -1 3 45f-9c9d-ae1-c93 2 ac7a-2560-c083-45b8
# inserting keyword relationship 45f-9c9d-ae1-c93 109
# inserting weapon Xenos Claws and Teeth 4+ 5 0 1 159-de40-be0e-b0d4 3 ac7a-2560-c083-45b8
# inserting weapon Impaler Cannon 4+ 5 -1 1 4296-8153-4146-2d5d 4 ac7a-2560-c083-45b8
# inserting keyword relationship 4296-8153-4146-2d5d 77
# inserting keyword relationship 4296-8153-4146-2d5d 89
# inserting unit cost ac7a-2560-c083-45b8 100 default
# inserting unit cost ac7a-2560-c083-45b8 200 atLeast 4
# inserting unit Tyrannofex  1705-379b-330d-36d4 b984-7317-81cc-20f
# inserting model 4869-ad8f-b75e-8a Tyrannofex 9" 12 16 8+ 2+ 1705-379b-330d-36d4 5
# inserting weapon Fleshborer Hive 3+ 5 0 1 a94a-a97b-c54-3ccf 20 1705-379b-330d-36d4
# inserting keyword relationship a94a-a97b-c54-3ccf 77
# inserting keyword relationship a94a-a97b-c54-3ccf 80
# inserting keyword relationship a94a-a97b-c54-3ccf 85
# inserting weapon Acid Spray N/A 6 -2 2 d526-3e7e-ecd2-97f3 D6+6 1705-379b-330d-36d4
# inserting keyword relationship d526-3e7e-ecd2-97f3 78
# inserting weapon Rupture Cannon 3+ 18 -4 2D6 3040-2e2-ec95-592d 2 1705-379b-330d-36d4
# inserting keyword relationship 3040-2e2-ec95-592d 77
# inserting weapon Powerful Limbs 3+ 8 0 2 bf87-80b8-ef8f-9514 4 1705-379b-330d-36d4
# inserting unit cost 1705-379b-330d-36d4 190 default
# inserting unit Tyrannocyte  fada-677a-f6a4-cd12 b984-7317-81cc-20f
# inserting model 2202-44e7-b5c0-ad6b Tyrannocyte 8" 9 10 8+ 3+ fada-677a-f6a4-cd12 2
# inserting weapon Tyrannocyte Bio-weapons 4+ 5 -1 2 97d8-b44e-edaf-2f93 5 fada-677a-f6a4-cd12
# inserting weapon Flensing Whips 4+ 7 -1 2 3751-5833-40ca-73b8 6 fada-677a-f6a4-cd12
# inserting unit cost fada-677a-f6a4-cd12 105 default
# inserting unit Hive Crone  93aa-dd13-de9d-402b b984-7317-81cc-20f
# inserting model 452b-84ef-66bb-c0a1 Hive Crone 20+" 9 12 8+ 3+ 93aa-dd13-de9d-402b 0
# inserting weapon Drool Cannon N/A 6 -1 1 5be8-54a0-e5d0-3e7f 2D6 93aa-dd13-de9d-402b
# inserting keyword relationship 5be8-54a0-e5d0-3e7f 78
# inserting weapon Tentaclids 3++ 7 0 2 8089-203-7e0c-cea5 4 93aa-dd13-de9d-402b
# inserting keyword relationship 8089-203-7e0c-cea5 93
# inserting keyword relationship 8089-203-7e0c-cea5 73
# inserting weapon Thorax Spur 3+ 10 -3 D6 f838-af93-4c1a-1c1a 1 93aa-dd13-de9d-402b
# inserting keyword relationship f838-af93-4c1a-1c1a 107
# inserting keyword relationship f838-af93-4c1a-1c1a 96
# inserting unit cost 93aa-dd13-de9d-402b 200 default
# inserting unit Harpy  c679-b06a-750b-e7f7 b984-7317-81cc-20f
# inserting model eec4-96a5-bff1-8d07 Harpy 20+" 9 12 8+ 3+ c679-b06a-750b-e7f7 0
# inserting weapon Twin Stranglethorn Cannon 2+ 7 -1 2 a72d-c8af-581e-dbbb D6+1 c679-b06a-750b-e7f7
# inserting keyword relationship a72d-c8af-581e-dbbb 88
# inserting keyword relationship a72d-c8af-581e-dbbb 85
# inserting weapon Twin Heavy Venom Cannon 3+ 9 -2 3 c2e1-bb76-49dc-acaf D3 c679-b06a-750b-e7f7
# inserting keyword relationship c2e1-bb76-49dc-acaf 88
# inserting keyword relationship c2e1-bb76-49dc-acaf 85
# inserting unit cost c679-b06a-750b-e7f7 215 default
# inserting unit Sporocyst  2cdd-3bf1-55e0-7641 b984-7317-81cc-20f
# inserting model 5054-55c7-17ab-87cc Sporocyst - 10 10 8+ 3+ 2cdd-3bf1-55e0-7641 0
# inserting weapon Sporocyst Bio-weapon 4+ 5 -1 2 1be7-213b-cf9b-dbff 10 2cdd-3bf1-55e0-7641
# inserting keyword Hive Defences
# inserting keyword relationship 1be7-213b-cf9b-dbff 137
# inserting weapon Flensing Whips 4+ 7 -1 1 5683-1921-e10d-612 6 2cdd-3bf1-55e0-7641
# inserting unit cost 2cdd-3bf1-55e0-7641 145 default
# inserting unit Psychophage  b6ac-f091-a018-dab2 b984-7317-81cc-20f
# inserting model 4174-2f06-c093-56fd Psychophage 8" 9 10 8+ 3+ b6ac-f091-a018-dab2 3
# inserting weapon Psycholastic Torrent N/A 6 -1 1 208d-6af9-f50c-f4f2 D6 b6ac-f091-a018-dab2
# inserting keyword relationship 208d-6af9-f50c-f4f2 87
# inserting keyword relationship 208d-6af9-f50c-f4f2 78
# inserting weapon Talons and Betentacled Maw 3+ 6 -1 2 1e16-7665-679d-7462 D6+1 b6ac-f091-a018-dab2
# inserting keyword relationship 1e16-7665-679d-7462 115
# inserting keyword relationship 1e16-7665-679d-7462 73
# inserting unit cost b6ac-f091-a018-dab2 95 default
# inserting unit Barbgaunts  6de-ccee-11b4-be3e b984-7317-81cc-20f
# inserting model dc3-bed1-ea8f-462f Barbgaunt 6" 4 2 8+ 4+ 6de-ccee-11b4-be3e 1
# inserting weapon Biocannon 4+ 5 0 1 b6d3-ee60-19f1-2405 D6 6de-ccee-11b4-be3e
# inserting keyword relationship b6d3-ee60-19f1-2405 88
# inserting keyword relationship b6d3-ee60-19f1-2405 77
# inserting weapon Xenos Claws and Teeth 4+ 4 0 1 66bb-a883-6588-9477 1 6de-ccee-11b4-be3e
# inserting unit cost 6de-ccee-11b4-be3e 55 default
# inserting unit cost 6de-ccee-11b4-be3e 110 greaterThan 5
# inserting unit Barbed Hierodule  afd0-a0ca-68c3-d912 b984-7317-81cc-20f
# inserting model 2fe6-3be-d60f-b788 Barbed Hierodule 8" 12 18 8+ 2+ afd0-a0ca-68c3-d912 5
# inserting weapon Bio-cannon 3+ 9 -2 2 581d-3649-e097-b6e5 D6+3 afd0-a0ca-68c3-d912
# inserting keyword relationship 581d-3649-e097-b6e5 88
# inserting weapon Hierodule scything talons 3+ 14 -2 D3+3 18f4-4462-750-11fb 8 afd0-a0ca-68c3-d912
# inserting unit cost afd0-a0ca-68c3-d912 340 default
# inserting unit Scythed Hierodule  218c-639e-22e0-59ce b984-7317-81cc-20f
# inserting model 80f5-a253-bac8-66b7 Scythed Hierodule 12" 12 18 8+ 2+ 218c-639e-22e0-59ce 5
# inserting weapon Hierodule scything talons 3+ 14 -2 D3+3 956e-76a1-b1ce-4526 10 218c-639e-22e0-59ce
# inserting weapon Bio-acid spray N/A 6 -2 1 6125-bd5f-4e70-554e 3D6 218c-639e-22e0-59ce
# inserting keyword relationship 6125-bd5f-4e70-554e 78
# inserting unit cost 218c-639e-22e0-59ce 330 default
# inserting unit Harridan  9b5c-3b5a-1f80-9a74 b984-7317-81cc-20f
# inserting model 1cbe-e64f-b19d-39b0 Harridan 20+" 10 30 8+ 3+ 9b5c-3b5a-1f80-9a74 0
# inserting weapon Dire bio-cannon 3+ 10 -3 3 fbb-c2d0-d589-6f5 D6+6 9b5c-3b5a-1f80-9a74
# inserting keyword relationship fbb-c2d0-d589-6f5 88
# inserting weapon Gargantuan scything talons 3+ 14 -2 D6 3f65-cba6-88b4-5ca 6 9b5c-3b5a-1f80-9a74
# inserting unit cost 9b5c-3b5a-1f80-9a74 610 default
# inserting unit Hierophant  fbc0-3a2b-1d7d-23d9 b984-7317-81cc-20f
# inserting model b4a6-82bd-fa8f-4235 Hierophant 12" 14 30 8+ 2+ fbc0-3a2b-1d7d-23d9 12
# inserting weapon Dire bio-cannon 3+ 10 -3 3 6141-7651-2d71-6f22 D6+6 fbc0-3a2b-1d7d-23d9
# inserting keyword relationship 6141-7651-2d71-6f22 88
# inserting weapon Titanic scything talons 3+ 20 -2 D6+1 728d-c54f-c1c4-2b3c 8 fbc0-3a2b-1d7d-23d9
# inserting weapon Lashwhip pods 3+ 5 -1 1 43ad-d7e-d788-e5bf 10 fbc0-3a2b-1d7d-23d9
# inserting keyword relationship 43ad-d7e-d788-e5bf 96
# inserting weapon Bio-plasma torrent N/A 7 -2 1 db9f-40a6-82da-befd 3D6 fbc0-3a2b-1d7d-23d9
# inserting keyword relationship db9f-40a6-82da-befd 70
# inserting keyword relationship db9f-40a6-82da-befd 78
# inserting unit cost fbc0-3a2b-1d7d-23d9 810 default
# inserting unit Genestealers  853e-48b8-4cc5-3704 b984-7317-81cc-20f
# inserting model 6d0d-9223-8bf3-353 Genestealers 8" 4 2 7+ 5+ 853e-48b8-4cc5-3704 1
# inserting weapon Genestealers claws and talons 2+ 4 -2 1 53b5-899c-4c1e-53a3 4 853e-48b8-4cc5-3704
# inserting unit cost 853e-48b8-4cc5-3704 75 default
# inserting unit Raveners  3f5-f7d6-1ce8-e6b9 b984-7317-81cc-20f
# inserting model 5103-b9e6-37f-80a9 Raveners 10" 5 3 8+ 5+ 3f5-f7d6-1ce8-e6b9 1
# inserting weapon Thoracic bio-weapon 4+ 4 0 1 8c6-7839-21c1-8a95 3 3f5-f7d6-1ce8-e6b9
# inserting keyword relationship 8c6-7839-21c1-8a95 70
# inserting unit cost 3f5-f7d6-1ce8-e6b9 75 default
# inserting unit Neurolictor  642f-9302-4fdc-ab68 b984-7317-81cc-20f
# inserting model fe95-bd06-986-961b Neurolictor 8" 5 7 7+ 4+ 642f-9302-4fdc-ab68 1
# inserting weapon Piercing Claws and Talons 2+ 6 -2 1 10fd-5ae9-79e8-cbd1 6 642f-9302-4fdc-ab68
# inserting keyword relationship 10fd-5ae9-79e8-cbd1 84
# inserting unit cost 642f-9302-4fdc-ab68 80 default
# inserting unit Norn Assimilator  6a9b-8e2f-edac-fa2d b984-7317-81cc-20f
# inserting model 36d4-99f2-1830-b57 Norn Assimilator 10" 11 16 7+ 2+ 6a9b-8e2f-edac-fa2d 5
# inserting weapon Monsterous Scything Talons 2+ 9 -2 3 d4b2-885d-1138-ee11 6 6a9b-8e2f-edac-fa2d
# inserting weapon Toxinjecter Harpoon 2+ 12 -3 D6+1 c174-a05a-1240-f935 4 6a9b-8e2f-edac-fa2d
# inserting keyword relationship c174-a05a-1240-f935 96
# inserting weapon Toxinjecter Harpoon 2+ 12 -3 D6+1 ffca-3eb5-e42f-f935 2 6a9b-8e2f-edac-fa2d
# inserting keyword Harpooned
# inserting keyword relationship ffca-3eb5-e42f-f935 138
# inserting unit cost 6a9b-8e2f-edac-fa2d 290 default
# inserting unit Norn Emissary  5720-2873-8c2c-edc3 b984-7317-81cc-20f
# inserting model 5942-e5c1-8f5d-b94c Norn Emissary 10" 11 16 7+ 2+ 5720-2873-8c2c-edc3 5
# inserting weapon ➤ Psychic Tendril - Neuroparasite 2+ 8 -2 D3 6874-7f26-f287-75b2 2 5720-2873-8c2c-edc3
# inserting keyword relationship 6874-7f26-f287-75b2 84
# inserting keyword relationship 6874-7f26-f287-75b2 86
# inserting weapon ➤ Psychic Tendril 2+ 12 -3 D6 b22f-1012-772-79bb 2 5720-2873-8c2c-edc3
# inserting keyword relationship b22f-1012-772-79bb 79
# inserting keyword relationship b22f-1012-772-79bb 86
# inserting weapon ➤ Psychic Tendril - Blast 2+ 6 -2 1 34f1-b5d9-74bb-5d1e 2D6 5720-2873-8c2c-edc3
# inserting keyword relationship 34f1-b5d9-74bb-5d1e 88
# inserting keyword relationship 34f1-b5d9-74bb-5d1e 86
# inserting weapon Monsterous Scything Talons 2+ 9 -2 3 3682-2b85-bde3-4113 6 5720-2873-8c2c-edc3
# inserting weapon Monsterous Rending Talons 2+ 7 -2 2 ee40-6-e50c-1761 4 5720-2873-8c2c-edc3
# inserting keyword relationship ee40-6-e50c-1761 96
# inserting unit cost 5720-2873-8c2c-edc3 275 default
# inserting unit Terror of Vardenghast  cc4a-75ac-22a8-77a7 b984-7317-81cc-20f
# inserting model b88-e5ec-3973-65d0 Terror of Vardenghast 12" 5 6 7+ 4+ cc4a-75ac-22a8-77a7 1
# inserting weapon Prime Talons 2+ 6 -1 2 8a71-751d-7cb3-21ee 6 cc4a-75ac-22a8-77a7
# ingesting for file: Unaligned Forces.cat
# inserting ally relationship dfcf-1214-b57-2205 581a-46b9-5b86-44b7
# inserting ally relationship 34a5-8c7e-f468-82d1 dfcf-1214-b57-2205
# inserting ally relationship 38de-521f-1ce0-44a0 dfcf-1214-b57-2205
# inserting ally relationship 1f1-47f9-a3a4-9bfb dfcf-1214-b57-2205
# inserting ally relationship b45c-af22-788a-dfd6 581a-46b9-5b86-44b7
# inserting ally relationship d265-877b-e03d-30ca 8106-aad2-918a-9ac
# inserting ally relationship d265-877b-e03d-30ca b45c-af22-788a-dfd6
# inserting ally relationship d265-877b-e03d-30ca 7481-280e-b55e-7867
# inserting ally relationship 46d8-abc8-ef3a-9f85 8106-aad2-918a-9ac
# inserting ally relationship 46d8-abc8-ef3a-9f85 b45c-af22-788a-dfd6
# inserting ally relationship 46d8-abc8-ef3a-9f85 7481-280e-b55e-7867
# inserting ally relationship c8da-e875-58f7-f6d6 46d8-abc8-ef3a-9f85
# inserting ally relationship c8da-e875-58f7-f6d6 b45c-af22-788a-dfd6
# inserting ally relationship c8da-e875-58f7-f6d6 7481-280e-b55e-7867
# inserting ally relationship 5108-f98-63c2-53cb 46d8-abc8-ef3a-9f85
# inserting ally relationship 5108-f98-63c2-53cb b45c-af22-788a-dfd6
# inserting ally relationship 5108-f98-63c2-53cb 7481-280e-b55e-7867
# inserting ally relationship 1069-10ff-3ba9-873b 46d8-abc8-ef3a-9f85
# inserting ally relationship 1069-10ff-3ba9-873b b45c-af22-788a-dfd6
# inserting ally relationship 1069-10ff-3ba9-873b 7481-280e-b55e-7867
# inserting ally relationship 880c-c7e-4a43-a0c1 7481-280e-b55e-7867
# inserting ally relationship 880c-c7e-4a43-a0c1 b45c-af22-788a-dfd6
# inserting ally relationship df9a-59b2-f464-59ad 46d8-abc8-ef3a-9f85
# inserting ally relationship df9a-59b2-f464-59ad b45c-af22-788a-dfd6
# inserting ally relationship df9a-59b2-f464-59ad 7481-280e-b55e-7867
# inserting ally relationship 3bdf-a114-5035-c6ac 5a44-f048-114b-e3ff
# inserting ally relationship 3bdf-a114-5035-c6ac 581a-46b9-5b86-44b7
# inserting ally relationship b39e-4401-8f3e-fdf7 25dd-7aa0-6bf4-f2d5
# inserting ally relationship b39e-4401-8f3e-fdf7 7481-280e-b55e-7867
# inserting ally relationship 1f19-6509-d906-ca10 25dd-7aa0-6bf4-f2d5
# inserting ally relationship 1f19-6509-d906-ca10 7481-280e-b55e-7867
# inserting ally relationship 77b9-2f66-3f9b-5cf3 25dd-7aa0-6bf4-f2d5
# inserting ally relationship 77b9-2f66-3f9b-5cf3 b00-cd86-4b4c-97ba
# inserting ally relationship 77b9-2f66-3f9b-5cf3 7481-280e-b55e-7867
# inserting ally relationship bdc0-c0d-72d7-87e2 7481-280e-b55e-7867
# inserting ally relationship bdc0-c0d-72d7-87e2 1b6d-dc06-5db9-c7d1
# inserting ally relationship bdc0-c0d-72d7-87e2 b00-cd86-4b4c-97ba
# inserting ally relationship b00-cd86-4b4c-97ba 581a-46b9-5b86-44b7
# inserting ally relationship b00-cd86-4b4c-97ba 7481-280e-b55e-7867
# inserting ally relationship b00-cd86-4b4c-97ba 1b6d-dc06-5db9-c7d1
# inserting ally relationship b0ae-12a5-c84-ea45 5a44-f048-114b-e3ff
# inserting ally relationship b0ae-12a5-c84-ea45 25dd-7aa0-6bf4-f2d5
# inserting ally relationship b0ae-12a5-c84-ea45 7481-280e-b55e-7867
# inserting ally relationship 36d3-36bc-68dd-40ac e0af-67df-9d63-8fb7
# inserting ally relationship 4ef9-15ce-e3e6-36de e0af-67df-9d63-8fb7
# inserting ally relationship 4ef9-15ce-e3e6-36de 25dd-7aa0-6bf4-f2d5
# inserting ally relationship 470a-6daa-9014-12df e0af-67df-9d63-8fb7
# inserting ally relationship 470a-6daa-9014-12df 25dd-7aa0-6bf4-f2d5
# inserting ally relationship f89b-84e0-6e3b-f1e2 e0af-67df-9d63-8fb7
# inserting ally relationship 50c4-3e83-fe54-97c4 25dd-7aa0-6bf4-f2d5
# inserting ally relationship 50c4-3e83-fe54-97c4 7481-280e-b55e-7867
# inserting ally relationship 5d6e-fd3-330a-11dd e0af-67df-9d63-8fb7
# inserting ally relationship 25dd-7aa0-6bf4-f2d5 1b6d-dc06-5db9-c7d1
# inserting ally relationship 25dd-7aa0-6bf4-f2d5 7481-280e-b55e-7867
# inserting ally relationship f27e-18c0-b73e-748e e0af-67df-9d63-8fb7
# inserting ally relationship f27e-18c0-b73e-748e 25dd-7aa0-6bf4-f2d5
# inserting ally relationship 6e59-e1ee-47ad-6ce5 e0af-67df-9d63-8fb7
# inserting ally relationship 6e59-e1ee-47ad-6ce5 25dd-7aa0-6bf4-f2d5
# inserting ally relationship 2261-79a5-19d9-1668 e0af-67df-9d63-8fb7
# inserting ally relationship 2261-79a5-19d9-1668 25dd-7aa0-6bf4-f2d5
# inserting ally relationship e0af-67df-9d63-8fb7 b00-cd86-4b4c-97ba
# inserting ally relationship e0af-67df-9d63-8fb7 7481-280e-b55e-7867
# inserting ally relationship e0af-67df-9d63-8fb7 1b6d-dc06-5db9-c7d1
# inserting ally relationship 94bb-3284-ee14-57a1 e0af-67df-9d63-8fb7
# inserting ally relationship 94bb-3284-ee14-57a1 25dd-7aa0-6bf4-f2d5
# inserting ally relationship 4029-9237-e8db-af55 e0af-67df-9d63-8fb7
# inserting ally relationship 4029-9237-e8db-af55 25dd-7aa0-6bf4-f2d5
# inserting ally relationship 67c1-fc13-f9a1-cbbf e0af-67df-9d63-8fb7
# inserting ally relationship 67c1-fc13-f9a1-cbbf 25dd-7aa0-6bf4-f2d5
# inserting ally relationship f616-3f08-ee8e-3349 581a-46b9-5b86-44b7
# inserting ally relationship b654-a18a-ea1-3bf2 581a-46b9-5b86-44b7
# inserting ally relationship a55f-b7b3-6c65-a05f 581a-46b9-5b86-44b7
# inserting ally relationship d81a-61dd-6d27-a3ce 581a-46b9-5b86-44b7
# inserting ally relationship b984-7317-81cc-20f 581a-46b9-5b86-44b7
