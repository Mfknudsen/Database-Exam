# %%
import xml.etree.ElementTree as ET
import mysql.connector
import logging
import uuid

# %%
def connect_to_db():
    return mysql.connector.connect(
        host="localhost",
        user="root",
        password="AmeSame420",
        database="mydb"
    )


ns = {'ns': 'http://www.battlescribe.net/schema/catalogueSchema'}


def insert_faction(root, cursor):
    _name = root.get('name')
    _description = root.get('description')
    if _description is None:
        _description = ""
    _id = root.get('id')

    sql = "INSERT INTO Faction (name, description, id) VALUES (%s, %s,%s)"
    try:
        cursor.execute(sql, (_name, _description, _id))
    except Exception as e:
        logging.error("Error at %s", "insert_faction", exc_info=e)
        print(e)

    return _id


def insert_unit2(cursor, root, faction_id):
    sharedSelectionEntries = root.find('ns:sharedSelectionEntries', ns)
    for selectionEntry in sharedSelectionEntries:
        if "[Legends]" not in selectionEntry.get("name"):
            if selectionEntry.get("type") == "model" or selectionEntry.get("type") == "unit":

                _name = selectionEntry.get("name")
                _description = selectionEntry.get("description")
                _description = ""
                _id = selectionEntry.get("id")

                sql = "INSERT INTO Unit (name, description, id, faction_id) VALUES (%s, %s,%s,%s)"
                try:
                    cursor.execute(sql, (_name, _description, _id, faction_id))
                    parse_selectionEntry(cursor, selectionEntry, _id)
                    insert_keywords(cursor, selectionEntry, _id)
                except Exception as e:
                    logging.error("Error at %s", "insert_unit", exc_info=e)
                    print(e)

def insert_keywords(cursor, selectionEntry, unit_id):
    keywords = selectionEntry.findall(".//ns:categoryLink", ns)
    for keyword in keywords:
        _name = keyword.get("name")
        _id = keyword.get("targetId")
        sql = "INSERT IGNORE INTO ModelKeyWord (text, id) VALUES (%s, %s)"
        sql_map = "INSERT IGNORE INTO unit_has_ModelKeyword (Unit_id, ModelKeyword_id) VALUES (%s, %s)"
        try:
            cursor.execute(sql, (_name, _id))
            cursor.execute(sql_map, (unit_id, _id))
        except Exception as e:
            logging.error("Error at %s", "insert_keywords", exc_info=e)
            print(e)

def parse_selectionEntry(cursor, selectionEntry, unit_id):
    profiles = selectionEntry.findall(".//ns:profile", ns)

    for profile in profiles:
        if profile.get("typeName") == "Unit" or profile.get("typeName") == "Model":
            insert_model(cursor, profile, unit_id)
        if profile.get("typeName") == "Abilities":
            insert_abilities(cursor, profile, unit_id)
        if profile.get("typeName") == "Ranged Weapons" or profile.get("typeName") == "Melee Weapons":
            insert_weapons(cursor, profile, unit_id)
            print("insert_weapons")

def insert_weapons(cursor, profile, unit_id):
    _name = profile.get("name")
    _id = profile.get("id")
    c = profile.find(".//ns:characteristics", ns)

    _range = None
    _strength = None
    _ap = None
    _damage = None
    _attack = None
    _hit = None


    for characteristic in c:
        if characteristic.get("name") == "Range":
            _range = characteristic.text
        if characteristic.get("name") == "S":
            _strength = characteristic.text
        if characteristic.get("name") == "AP":
            _ap = characteristic.text
        if characteristic.get("name") == "D":
            _damage = characteristic.text
        if characteristic.get("name") == "A":
            _attack = characteristic.text
        if characteristic.get("name") == "WS":
            _hit = characteristic.text
        if characteristic.get("name") == "BS":
            _hit = characteristic.text
        if characteristic.get("name") == "KeyWords":
            insert_weapon_keywords(cursor, profile, unit_id)
    sql = "INSERT INTO weapon (name, weapon_range, hit_skill, strength, armor_piercing, damage, id, attack, unit_id) VALUES (%s, %s,%s,%s,%s,%s,%s,%s,%s)"
    print(_name, _range, _hit, _strength, _ap, _damage, _id, _attack, unit_id)
    try:
        cursor.execute(sql, (_name, _range, _hit, _strength, _ap, _damage, _id, _attack, unit_id))
    except Exception as e:
        logging.error("Error at %s", "insert_weapons", exc_info=e)
        print(e)

def insert_weapon_keywords(cursor, profile, unit_id):
    keywords = profile.findall(".//ns:categoryLink", ns)
    for keyword in keywords:
        _name = keyword.get("name")
        _id = keyword.get("targetId")
        sql = "INSERT IGNORE INTO WeaponKeyWord (text, id) VALUES (%s, %s)"
        sql_map = "INSERT IGNORE INTO weapon_has_WeaponKeyword (Weapon_id, WeaponKeyword_id) VALUES (%s, %s)"
        try:
            cursor.execute(sql, (_name, _id))
            cursor.execute(sql_map, (unit_id, _id))
        except Exception as e:
            logging.error("Error at %s", "insert_keywords", exc_info=e)
            print(e)

def insert_abilities(cursor, profile, unit_id):
    _name = profile.get("name")
    _id = profile.get("id")
    _description = profile.findall(".//ns:characteristic", ns)[0].text

    sql = "INSERT INTO modelability (name, description, id) VALUES (%s, %s,%s)"
    sql_map = "INSERT INTO unit_has_modelability (unit_id, ModelAbility_id) VALUES (%s, %s)"
    try:
        cursor.execute(sql, (_name, _description, _id))
        cursor.execute(sql_map, (unit_id, _id))
    except Exception as e:
        logging.error("Error at %s", "insert_abilities", exc_info=e)
        print(e)

def create_keywords_sql(cursor, keywords, _id):
    _id = str(uuid.uuid4())
    for keyword in keywords:
        # Check if the keyword already exists
        cursor.execute("SELECT id FROM weaponkeyword WHERE text = %s", (keyword,))
        result = cursor.fetchone()

        # If the keyword does not exist, insert it
        if result is None:
            cursor.execute("INSERT INTO weaponkeyword (id, text) VALUES (%s, %s)", (_id, keyword))


def insert_model(cursor, model, unit_id):
    _name = model.get("name")
    _id = model.get("id")

    move = None
    leadership = None
    save = None
    toughness = None
    wounds = None
    oc = None
    keywords = []
    for characteristics in model.findall(".//ns:characteristic", ns):

        if characteristics.get("name") == "M":
            move = characteristics.text
        elif characteristics.get("name") == "LD":
            leadership = characteristics.text
        elif characteristics.get("name") == "SV":
            save = characteristics.text
        elif characteristics.get("name") == "T":
            toughness = characteristics.text
        elif characteristics.get("name") == "W":
            wounds = characteristics.text
        elif characteristics.get("name") == "OC":
            oc = characteristics.text


        sql_models = "INSERT INTO Model (id, name, move, toughness,wounds, leadership, save, unit_id, oc) VALUES (%s, %s,%s,%s, %s, %s,%s,%s,%s)"


    try:
        cursor.execute(sql_models, (_id, _name, move, toughness, wounds, leadership, save, unit_id, oc))

    except Exception as e:
        logging.error("Error at %s", "insert_model", exc_info=e)
        print(e)


def parse_cat_file(filename):
    tree = ET.parse(filename)
    root = tree.getroot()
    return root


def ingest_data(root, cursor):
    faction_id = insert_faction(root, cursor)
    insert_unit2(cursor, root, faction_id)
    db_connection.commit()


def clear_all_tables(cursor):
    # Get all table names
    cursor.execute("SHOW TABLES")
    tables = cursor.fetchall()

    # Iterate over all tables and delete all records
    for table in tables:
        try:
            cursor.execute(f"DELETE FROM `{table[0]}`")
        except mysql.connector.Error as err:
            print(f"Something went wrong: {err}")

# %%
db_connection = connect_to_db()
cursor = db_connection.cursor()

# %%
root = parse_cat_file("./wh40k-10e/Imperium - Space Marines.cat")
clear_all_tables(cursor)
ingest_data(root, cursor)
# Out:
# ERROR:root:Error at insert_faction
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry 'e0af-67df-9d63-8fb7' for key 'faction.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 22, in insert_faction
#     cursor.execute(sql, (_name, _description, _id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry 'e0af-67df-9d63-8fb7' for key 'faction.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '1d56-1cc3-de57-10e2' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '1d56-1cc3-de57-10e2' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry 'a976-7cd5-9657-d91a' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry 'a976-7cd5-9657-d91a' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry 'dc24-dd64-5d97-df3c' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry 'dc24-dd64-5d97-df3c' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '1319-45d-bb95-dfd4' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '1319-45d-bb95-dfd4' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '8da0-4570-c3c-819f' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '8da0-4570-c3c-819f' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry 'b007-fc7b-8e4a-b017' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry 'b007-fc7b-8e4a-b017' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry 'a10b-fbfe-b1fa-6f0c' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry 'a10b-fbfe-b1fa-6f0c' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '7324-e591-939b-b675' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '7324-e591-939b-b675' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '70dc-ed18-2788-b35a' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '70dc-ed18-2788-b35a' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '527c-120e-9e4e-9bfe' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '527c-120e-9e4e-9bfe' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry 'c09a-6504-d25f-477' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry 'c09a-6504-d25f-477' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '1117-cda-7f74-196b' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '1117-cda-7f74-196b' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '7044-bf1-f949-c32d' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '7044-bf1-f949-c32d' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '9e9c-bf4d-2d40-be82' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '9e9c-bf4d-2d40-be82' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '907f-11-c4d1-ec21' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '907f-11-c4d1-ec21' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry 'a7ae-e495-683b-7c90' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry 'a7ae-e495-683b-7c90' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '129d-2da5-66f3-f4ec' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '129d-2da5-66f3-f4ec' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry 'ae9a-10e3-8091-20' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry 'ae9a-10e3-8091-20' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '4808-a80b-309a-7933' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '4808-a80b-309a-7933' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '2a8a-522d-51e4-3abc' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '2a8a-522d-51e4-3abc' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '6ba0-cede-e278-f86b' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '6ba0-cede-e278-f86b' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '24df-fdd6-4d7b-fc0e' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '24df-fdd6-4d7b-fc0e' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry 'd204-13c6-dab1-ecdc' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry 'd204-13c6-dab1-ecdc' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '1d94-b3c8-9205-827e' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '1d94-b3c8-9205-827e' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '5dc7-aa6c-7053-cede' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '5dc7-aa6c-7053-cede' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '1c00-9398-b9e7-446a' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '1c00-9398-b9e7-446a' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '8d7b-3dfe-7b91-2490' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '8d7b-3dfe-7b91-2490' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry 'b5e8-c34b-566b-8bda' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry 'b5e8-c34b-566b-8bda' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '97f6-b1f8-c72d-e826' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '97f6-b1f8-c72d-e826' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '3e14-2a-d358-6ada' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '3e14-2a-d358-6ada' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '9cb9-9ab5-727f-80e5' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '9cb9-9ab5-727f-80e5' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '993a-9cbc-8052-e40' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '993a-9cbc-8052-e40' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '9489-445c-f950-7292' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '9489-445c-f950-7292' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '7102-b3a4-9bfc-1b84' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '7102-b3a4-9bfc-1b84' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry 'd6c3-e9d2-430d-6c2f' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry 'd6c3-e9d2-430d-6c2f' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry 'c570-c6ba-c9dc-5a44' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry 'c570-c6ba-c9dc-5a44' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '3f4c-1e67-66dc-ffa5' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '3f4c-1e67-66dc-ffa5' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry 'a3ea-7a0d-fef8-23bf' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
# ...
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry 'fc7f-8176-c10c-ca8' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry 'fc7f-8176-c10c-ca8' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '8dcb-987c-1ab4-b976' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '8dcb-987c-1ab4-b976' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '6c10-5b51-5bc0-8d2c' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '6c10-5b51-5bc0-8d2c' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '98db-fff3-b1b2-e22f' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '98db-fff3-b1b2-e22f' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '3416-dfee-84ee-e21d' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '3416-dfee-84ee-e21d' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry 'cdd9-efda-95-e7b2' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry 'cdd9-efda-95-e7b2' for key 'unit.PRIMARY'
# ERROR:root:Error at insert_unit
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 697, in cmd_query
#     self._cmysql.query(
# _mysql_connector.MySQLInterfaceError: Duplicate entry '2f2e-d99b-b235-163a' for key 'unit.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\krist\AppData\Local\Temp\ipykernel_22716\2910890322.py", line 43, in insert_unit2
#     cursor.execute(sql, (_name, _description, _id, faction_id))
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py", line 372, in execute
#     result = self._cnx.cmd_query(
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py", line 102, in wrapper
#     return method(cnx, *args, **kwargs)
#   File "C:\Users\krist\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py", line 705, in cmd_query
#     raise get_mysql_exception(
# mysql.connector.errors.IntegrityError: 1062 (23000): Duplicate entry '2f2e-d99b-b235-163a' for key 'unit.PRIMARY'
# Something went wrong: 1451 (23000): Cannot delete or update a parent row: a foreign key constraint fails (`mydb`.`unit`, CONSTRAINT `fk_Unit_Faction1` FOREIGN KEY (`faction_id`) REFERENCES `faction` (`id`))
# Something went wrong: 1451 (23000): Cannot delete or update a parent row: a foreign key constraint fails (`mydb`.`unit_has_modelability`, CONSTRAINT `fk_Unit_has_ModelAbility_ModelAbility1` FOREIGN KEY (`ModelAbility_id`) REFERENCES `modelability` (`id`))
# Something went wrong: 1451 (23000): Cannot delete or update a parent row: a foreign key constraint fails (`mydb`.`unit_has_modelkeyword`, CONSTRAINT `fk_Unit_has_ModelKeyword_ModelKeyword1` FOREIGN KEY (`ModelKeyword_id`) REFERENCES `modelkeyword` (`id`))
# Something went wrong: 1451 (23000): Cannot delete or update a parent row: a foreign key constraint fails (`mydb`.`unit_has_modelability`, CONSTRAINT `fk_Unit_has_ModelAbility_Unit1` FOREIGN KEY (`Unit_id`) REFERENCES `unit` (`id`))
# 1062 (23000): Duplicate entry 'e0af-67df-9d63-8fb7' for key 'faction.PRIMARY'
# 1062 (23000): Duplicate entry '1d56-1cc3-de57-10e2' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'a976-7cd5-9657-d91a' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'dc24-dd64-5d97-df3c' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '1319-45d-bb95-dfd4' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '8da0-4570-c3c-819f' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'b007-fc7b-8e4a-b017' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'a10b-fbfe-b1fa-6f0c' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '7324-e591-939b-b675' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '70dc-ed18-2788-b35a' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '527c-120e-9e4e-9bfe' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'c09a-6504-d25f-477' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '1117-cda-7f74-196b' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '7044-bf1-f949-c32d' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '9e9c-bf4d-2d40-be82' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '907f-11-c4d1-ec21' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'a7ae-e495-683b-7c90' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '129d-2da5-66f3-f4ec' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'ae9a-10e3-8091-20' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '4808-a80b-309a-7933' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '2a8a-522d-51e4-3abc' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '6ba0-cede-e278-f86b' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '24df-fdd6-4d7b-fc0e' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'd204-13c6-dab1-ecdc' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '1d94-b3c8-9205-827e' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '5dc7-aa6c-7053-cede' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '1c00-9398-b9e7-446a' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '8d7b-3dfe-7b91-2490' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'b5e8-c34b-566b-8bda' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '97f6-b1f8-c72d-e826' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '3e14-2a-d358-6ada' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '9cb9-9ab5-727f-80e5' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '993a-9cbc-8052-e40' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '9489-445c-f950-7292' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '7102-b3a4-9bfc-1b84' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'd6c3-e9d2-430d-6c2f' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'c570-c6ba-c9dc-5a44' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '3f4c-1e67-66dc-ffa5' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'a3ea-7a0d-fef8-23bf' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'edf8-643b-cd1-3c11' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'ae85-3e33-217d-7413' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'd4c8-dd6a-cd7a-ccc3' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '31a-6c3e-5843-4023' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '7814-107b-a498-96f6' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'ed20-824b-7419-aebc' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '6b89-8147-9b6b-6db1' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'cb6d-201f-4888-3027' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '8cca-9318-3bec-d360' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '1d65-c592-2e16-b045' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'd361-a36e-1448-264d' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'e8e-fc5c-c689-99ca' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '9259-f166-15f2-7f79' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'a14e-75ca-ef91-397f' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'ed11-25b9-a0eb-89f4' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'bfb1-7512-e1a3-9fa2' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '4d57-c5c8-c1a1-e8a6' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '3d99-47aa-8cf3-883f' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '1bb6-878e-7af1-5bdb' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '469b-3370-30f3-473a' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '5882-9143-e7c5-ac11' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'ce15-e87e-7cff-b129' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '6dfd-beb0-5b01-b21e' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'fe0e-6070-e7b-d4b8' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '78eb-9334-f5c0-6095' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '137c-2add-1a51-ee96' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '2468-24f5-ad9b-8388' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'ceb5-55c7-2d49-d952' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'c026-b762-d0a6-5ef1' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '5d1d-2230-8199-3ab3' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '23f1-2df2-7085-cf41' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'e671-cd3a-2b03-3954' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '109f-f71d-56-d9eb' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '8a9d-11f-fad-bd0f' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'c6e9-c0c8-5f13-5771' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '6562-d718-b8e0-c457' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '9ca5-e5f4-f85d-bcca' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'fc7f-8176-c10c-ca8' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '8dcb-987c-1ab4-b976' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '6c10-5b51-5bc0-8d2c' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '98db-fff3-b1b2-e22f' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '3416-dfee-84ee-e21d' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry 'cdd9-efda-95-e7b2' for key 'unit.PRIMARY'
# 1062 (23000): Duplicate entry '2f2e-d99b-b235-163a' for key 'unit.PRIMARY'
